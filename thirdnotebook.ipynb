# %%
# Things to keep in mind with the data:
# (1) The calendar week for Walmart changes each year, so the holiday week may capture more or less days related 
# to the holiday
# (2) The data proportionally has more weeks that are not holidays compared to weeks that are a holiday, this could possibly 
# skew our results
# (3) We are only looking at 4 major holidays, we are not including local holidays, sports events and other events
# that could possibly have an effect on weekly sales
# (4) This dataset only pulls from 45 stores out of all of Walmarts locations across the United States, this subset may not be 
# an accurate depiction of Walmart as a whole

# %%
# %run secondnotebook.ipynb

# Import necessary modules
import pandas as pd
import csv
from scipy import stats
import os

# Rename dataframe to work with the code
walmart_clean = walmart_data

# Read in clean/transformed dataset
#walmart_clean = pd.read_csv("Project 1\Walmart.csv")
# Out:
# {'meta': {'code': 200},
#  'response': {'holidays': [{'country': {'id': 'us', 'name': 'United States'},
#                             'date': {'datetime': {'day': 1,
#                                                   'month': 1,
#                                                   'year': 2010},
#                                      'iso': '2010-01-01'},
#                             'description': "New Year's Day is the first day of "
#                                            'the Gregorian calendar, which is '
#                                            'widely used in many countries such '
#                                            'as the USA.',
#                             'locations': 'All',
#                             'name': "New Year's Day",
#                             'states': 'All',
#                             'type': ['National holiday']},
#                            {'country': {'id': 'us', 'name': 'United States'},
#                             'date': {'datetime': {'day': 6,
#                                                   'month': 1,
#                                                   'year': 2010},
#                                      'iso': '2010-01-06'},
#                             'description': 'Many people in the United States '
#                                            'annually observe Epiphany, or '
#                                            'Three Kings’ Day, on January 6. It '
#                                            'is a Christian observance and a '
#                                            'public holiday in the US Virgin '
#                                            'Islands.',
#                             'locations': 'All',
#                             'name': 'Epiphany',
#                             'states': 'All',
#                             'type': ['Christian']},
#                            {'country': {'id': 'us', 'name': 'United States'},
#                             'date': {'datetime': {'day': 7,
#                                                   'month': 1,
#                                                   'year': 2010},
#                                      'iso': '2010-01-07'},
#                             'description': 'Many Orthodox Christian churches '
#                                            'in countries such as the United '
#                                            'States observe Christmas Day on or '
#                                            'near January 7 in the Gregorian '
#                                            'calendar.',
#                             'locations': 'All',
#                             'name': 'Orthodox Christmas Day',
#                             'states': 'All',
#                             'type': ['Orthodox']},
#                            {'country': {'id': 'us', 'name': 'United States'},
#                             'date': {'datetime': {'day': 7,
#                                                   'month': 1,
#                                                   'year': 2010},
#                                      'iso': '2010-01-07'},
#                             'description': 'Many people celebrate '
#                                            'International Programmers’ Day on '
#                                            'January 7, while others observe '
#                                            'this event on the 256th day of the '
#                                            'year, usually on September 13 or '
#                                            'on September 12 in leap years.',
#                             'locations': 'All',
#                             'name': "International Programmers' Day",
#                             'states': 'All',
#                             'type': ['Worldwide observance']},
#                            {'country': {'id': 'us', 'name': 'United States'},
#                             'date': {'datetime': {'day': 13,
#                                                   'month': 1,
#                                                   'year': 2010},
#                                      'iso': '2010-01-13'},
#                             'description': 'Stephen Foster Memorial Day is '
#                                            'annually observed in the United '
#                                            'States on January 13. The day '
#                                            'remembers the achievements of '
#                                            'Stephen Foster, who is known as '
#                                            'the “father of American music”.',
#                             'locations': 'All',
#                             'name': 'Stephen Foster Memorial Day',
#                             'states': 'All',
#                             'type': ['Observance']},
#                            {'country': {'id': 'us', 'name': 'United States'},
#                             'date': {'datetime': {'day': 14,
#                                                   'month': 1,
#                                                   'year': 2010},
#                                      'iso': '2010-01-14'},
#                             'description': 'Many Orthodox Christian churches '
#                                            'in countries such as the United '
#                                            'States celebrate New Year’s Day on '
#                                            'January 14 in the Gregorian '
#                                            'calendar.',
#                             'locations': 'All',
#                             'name': 'Orthodox New Year',
#                             'states': 'All',
#                             'type': ['Orthodox']},
#                            {'country': {'id': 'us', 'name': 'United States'},
#                             'date': {'datetime': {'day': 15,
#                                                   'month': 1,
#                                                   'year': 2010},
#                                      'iso': '2010-01-15'},
#                             'description': 'Lee-Jackson Day is an annual state '
#                                            'holiday in Virginia, the United '
#                                            'States, on the Friday before '
#                                            'Martin Luther King Day in January.',
#                             'locations': 'VA',
#                             'name': 'Lee-Jackson Day',
#                             'states': [{'abbrev': 'VA',
#                                         'exception': None,
#                                         'id': 52,
#                                         'iso': 'us-va',
#                                         'name': 'Virginia'}],
#                             'type': ['Local holiday']},
#                            {'country': {'id': 'us', 'name': 'United States'},
#                             'date': {'datetime': {'day': 18,
#                                                   'month': 1,
#                                                   'year': 2010},
#                                      'iso': '2010-01-18'},
#                             'description': 'Martin Luther King Day marks the '
#                                            'anniversary of the date of birth '
#                                            'of the influential American civil '
#                                            'right leader of the same name.',
#                             'locations': 'All',
#                             'name': 'Martin Luther King Jr. Day',
#                             'states': 'All',
#                             'type': ['National holiday']},
#                            {'country': {'id': 'us', 'name': 'United States'},
#                             'date': {'datetime': {'day': 18,
#                                                   'month': 1,
#                                                   'year': 2010},
#                                      'iso': '2010-01-18'},
#                             'description': 'Robert E. Lee’s birthday is an '
#                                            'annual official state holiday that '
#                                            'is shared with Martin Luther '
#                                            'King’s birthday in some parts of '
#                                            'the US.',
#                             'locations': 'GA',
#                             'name': "Robert E. Lee's Birthday",
#                             'states': [{'abbrev': 'GA',
#                                         'exception': None,
#                                         'id': 13,
#                                         'iso': 'us-ga',
#                                         'name': 'Georgia'}],
#                             'type': ['Local holiday']},
#                            {'country': {'id': 'us', 'name': 'United States'},
#                             'date': {'datetime': {'day': 18,
#                                                   'month': 1,
#                                                   'year': 2010},
#                                      'iso': '2010-01-18'},
#                             'description': 'Robert E. Lee’s birthday is an '
#                                            'annual official state holiday that '
#                                            'is shared with Martin Luther '
#                                            'King’s birthday in some parts of '
#                                            'the US.',
#                             'locations': 'AL',
#                             'name': "Robert E. Lee's Birthday",
#                             'states': [{'abbrev': 'AL',
#                                         'exception': None,
#                                         'id': 1,
#                                         'iso': 'us-al',
#                                         'name': 'Alabama'}],
#                             'type': ['Local holiday']},
#                            {'country': {'id': 'us', 'name': 'United States'},
#                             'date': {'datetime': {'day': 18,
#                                                   'month': 1,
#                                                   'year': 2010},
#                                      'iso': '2010-01-18'},
#                             'description': 'Robert E. Lee’s birthday is an '
#                                            'annual official state holiday that '
#                                            'is shared with Martin Luther '
#                                            'King’s birthday in some parts of '
#                                            'the US.',
#                             'locations': 'AR',
#                             'name': "Robert E. Lee's Birthday",
#                             'states': [{'abbrev': 'AR',
#                                         'exception': None,
#                                         'id': 5,
#                                         'iso': 'us-ar',
#                                         'name': 'Arkansas'}],
#                             'type': ['Local holiday']},
#                            {'country': {'id': 'us', 'name': 'United States'},
#                             'date': {'datetime': {'day': 18,
#                                                   'month': 1,
#                                                   'year': 2010},
#                                      'iso': '2010-01-18'},
#                             'description': 'Robert E. Lee’s birthday is an '
#                                            'annual official state holiday that '
#                                            'is shared with Martin Luther '
#                                            'King’s birthday in some parts of '
#                                            'the US.',
#                             'locations': 'MS',
#                             'name': "Robert E. Lee's Birthday",
#                             'states': [{'abbrev': 'MS',
#                                         'exception': None,
#                                         'id': 28,
#                                         'iso': 'us-ms',
#                                         'name': 'Mississippi'}],
#                             'type': ['Local holiday']},
#                            {'country': {'id': 'us', 'name': 'United States'},
#                             'date': {'datetime': {'day': 18,
#                                                   'month': 1,
#                                                   'year': 2010},
#                                      'iso': '2010-01-18'},
#                             'description': 'Robert E. Lee’s birthday is an '
#                                            'annual official state holiday that '
#                                            'is shared with Martin Luther '
#                                            'King’s birthday in some parts of '
#                                            'the US.',
#                             'locations': 'All',
#                             'name': "Robert E. Lee's Birthday",
#                             'states': 'All',
#                             'type': ['Local holiday']},
#                            {'country': {'id': 'us', 'name': 'United States'},
#                             'date': {'datetime': {'day': 18,
#                                                   'month': 1,
#                                                   'year': 2010},
#                                      'iso': '2010-01-18'},
#                             'description': 'Idaho Human Rights Day is a state '
#                                            'holiday in Idaho, the United '
#                                            'States, on the third Monday of '
#                                            'January.',
#                             'locations': 'ID',
#                             'name': 'Idaho Human Rights Day',
#                             'states': [{'abbrev': 'ID',
#                                         'exception': None,
#                                         'id': 15,
#                                         'iso': 'us-id',
#                                         'name': 'Idaho'}],
#                             'type': ['Local holiday']},
#                            {'country': {'id': 'us', 'name': 'United States'},
#                             'date': {'datetime': {'day': 18,
#                                                   'month': 1,
#                                                   'year': 2010},
#                                      'iso': '2010-01-18'},
#                             'description': 'Civil Rights Day is on the third '
#                                            'Monday of January in Arizona and '
#                                            'New Hampshire. It honors civil '
#                                            'rights activists such as Martin '
#                                            'Luther King Jr.',
#                             'locations': 'NH',
#                             'name': 'Civil Rights Day',
#                             'states': [{'abbrev': 'NH',
#                                         'exception': None,
#                                         'id': 33,
#                                         'iso': 'us-nh',
#                                         'name': 'New Hampshire'}],
#                             'type': ['Local holiday']},
#                            {'country': {'id': 'us', 'name': 'United States'},
#                             'date': {'datetime': {'day': 18,
#                                                   'month': 1,
#                                                   'year': 2010},
#                                      'iso': '2010-01-18'},
#                             'description': 'Civil Rights Day is on the third '
#                                            'Monday of January in Arizona and '
#                                            'New Hampshire. It honors civil '
#                                            'rights activists such as Martin '
#                                            'Luther King Jr.',
#                             'locations': 'AZ',
#                             'name': 'Civil Rights Day',
#                             'states': [{'abbrev': 'AZ',
#                                         'exception': None,
#                                         'id': 4,
#                                         'iso': 'us-az',
#                                         'name': 'Arizona'}],
#                             'type': ['Local holiday']},
#                            {'country': {'id': 'us', 'name': 'United States'},
#                             'date': {'datetime': {'day': 19,
#                                                   'month': 1,
#                                                   'year': 2010},
#                                      'iso': '2010-01-19'},
#                             'description': 'Robert E. Lee’s birthday is an '
#                                            'annual official state holiday that '
#                                            'is shared with Martin Luther '
#                                            'King’s birthday in some parts of '
#                                            'the US.',
#                             'locations': 'FL',
#                             'name': "Robert E. Lee's Birthday",
#                             'states': [{'abbrev': 'FL',
#                                         'exception': None,
#                                         'id': 12,
#                                         'iso': 'us-fl',
#                                         'name': 'Florida'}],
#                             'type': ['Local holiday']},
#                            {'country': {'id': 'us', 'name': 'United States'},
#                             'date': {'datetime': {'day': 19,
#                                                   'month': 1,
#                                                   'year': 2010},
#                                      'iso': '2010-01-19'},
#                             'description': 'On Confederate Memorial Day '
#                                            'remembers the soldiers who died '
#                                            'fighting for the Confederate '
#                                            'States of America during the '
#                                            'American Civil War (1861-1865). It '
#                                            'is a state holiday in some parts '
#                                            'of the United States.',
#                             'locations': 'TX',
#                             'name': "Confederate Heroes' Day",
#                             'states': [{'abbrev': 'TX',
#                                         'exception': None,
#                                         'id': 48,
#                                         'iso': 'us-tx',
#                                         'name': 'Texas'}],
#                             'type': ['Local holiday']},
#                            {'country': {'id': 'us', 'name': 'United States'},
#                             'date': {'datetime': {'day': 27,
#                                                   'month': 1,
#                                                   'year': 2010},
#                                      'iso': '2010-01-27'},
#                             'description': "The United Nations' (UN) "
#                                            'International Day of Commemoration '
#                                            'in Memory of the Victims of the '
#                                            'Holocaust remembers those who died '
#                                            'and suffered during the Holocaust '
#                                            'before and during World War II. It '
#                                            'is on January 27 each year.',
#                             'locations': 'All',
#                             'name': 'International Day of Commemoration in '
#                                     'Memory of the Victims of the Holocaust',
#                             'states': 'All',
#                             'type': ['United Nations observance']},
#                            {'country': {'id': 'us', 'name': 'United States'},
#                             'date': {'datetime': {'day': 29,
#                                                   'month': 1,
#                                                   'year': 2010},
#                                      'iso': '2010-01-29'},
#                             'description': 'Kansas Day is an annual observance '
#                                            "that commemorates the state's "
#                                            'admission to the Union in 1861.',
#                             'locations': 'All',
#                             'name': 'Kansas Day',
#                             'states': 'All',
#                             'type': ['Observance']},
#                            {'country': {'id': 'us', 'name': 'United States'},
#                             'date': {'datetime': {'day': 30,
#                                                   'month': 1,
#                                                   'year': 2010},
#                                      'iso': '2010-01-30'},
#                             'description': 'Tu B’Shevat is known as the “New '
#                                            'Year for Trees”, is a Jewish '
#                                            'festival similar to Arbor Day.',
#                             'locations': 'All',
#                             'name': "Tu Bishvat/Tu B'Shevat",
#                             'states': 'All',
#                             'type': ['Hebrew']},
#                            {'country': {'id': 'us', 'name': 'United States'},
#                             'date': {'datetime': {'day': 31,
#                                                   'month': 1,
#                                                   'year': 2010},
#                                      'iso': '2010-01-31'},
#                             'description': 'World Leprosy Day brings awareness '
#                                            "of leprosy, also known as Hansen's "
#                                            'disease, and ways to prevent the '
#                                            'disease.',
#                             'locations': 'All',
#                             'name': 'World Leprosy Day',
#                             'states': 'All',
#                             'type': ['Worldwide observance']},
#                            {'country': {'id': 'us', 'name': 'United States'},
#                             'date': {'datetime': {'day': 1,
#                                                   'month': 2,
#                                                   'year': 2010},
#                                      'iso': '2010-02-01'},
#                             'description': 'National Freedom Day in the United '
#                                            'States is observed on February 1 '
#                                            'each year.',
#                             'locations': 'All',
#                             'name': 'National Freedom Day',
#                             'states': 'All',
#                             'type': ['Observance']},
#                            {'country': {'id': 'us', 'name': 'United States'},
#                             'date': {'datetime': {'day': 1,
#                                                   'month': 2,
#                                                   'year': 2010},
#                                      'iso': '2010-02-01'},
#                             'description': 'First Day of Black History Month '
#                                            'is a annual monthly observance in '
#                                            'the USA',
#                             'locations': 'All',
#                             'name': 'First Day of Black History Month',
#                             'states': 'All',
#                             'type': ['Observance']},
#                            {'country': {'id': 'us', 'name': 'United States'},
#                             'date': {'datetime': {'day': 2,
#                                                   'month': 2,
#                                                   'year': 2010},
#                                      'iso': '2010-02-02'},
#                             'description': 'World Wetlands Day raises '
#                                            'awareness about the important role '
#                                            'that the wetlands play in the '
#                                            'environment and in our lives.',
#                             'locations': 'All',
#                             'name': 'World Wetlands Day',
#                             'states': 'All',
#                             'type': ['Worldwide observance']},
#                            {'country': {'id': 'us', 'name': 'United States'},
#                             'date': {'datetime': {'day': 2,
#                                                   'month': 2,
#                                                   'year': 2010},
#                                      'iso': '2010-02-02'},
#                             'description': 'Many people in the United States '
#                                            'observe Groundhog Day on February '
#                                            '2.',
#                             'locations': 'All',
#                             'name': 'Groundhog Day',
#                             'states': 'All',
#                             'type': ['Observance']},
#                            {'country': {'id': 'us', 'name': 'United States'},
#                             'date': {'datetime': {'day': 4,
#                                                   'month': 2,
#                                                   'year': 2010},
#                                      'iso': '2010-02-04'},
#                             'description': 'World Cancer Day is an annual '
#                                            'global event on February 4 to '
#                                            'raise people’s awareness of '
#                                            'cancer.',
#                             'locations': 'All',
#                             'name': 'World Cancer Day',
#                             'states': 'All',
#                             'type': ['United Nations observance']},
#                            {'country': {'id': 'us', 'name': 'United States'},
#                             'date': {'datetime': {'day': 4,
#                                                   'month': 2,
#                                                   'year': 2010},
#                                      'iso': '2010-02-04'},
#                             'description': 'The life of American civil rights '
#                                            'leader Rosa Parks is celebrated in '
#                                            'the United States on either '
#                                            'February 4 or December 1.',
#                             'locations': 'CA',
#                             'name': 'Rosa Parks Day',
#                             'states': [{'abbrev': 'CA',
#                                         'exception': None,
#                                         'id': 7,
#                                         'iso': 'us-ca',
#                                         'name': 'California'}],
#                             'type': ['Local observance']},
#                            {'country': {'id': 'us', 'name': 'United States'},
#                             'date': {'datetime': {'day': 5,
#                                                   'month': 2,
#                                                   'year': 2010},
#                                      'iso': '2010-02-05'},
#                             'description': 'National Wear Red Day® raises '
#                                            'public awareness of heart disease '
#                                            'in women and ways to avoid and '
#                                            'combat this problem.',
#                             'locations': 'All',
#                             'name': 'National Wear Red Day',
#                             'states': 'All',
#                             'type': ['Observance']},
#                            {'country': {'id': 'us', 'name': 'United States'},
#                             'date': {'datetime': {'day': 6,
#                                                   'month': 2,
#                                                   'year': 2010},
#                                      'iso': '2010-02-06'},
#                             'description': 'The International Day of Zero '
#                                            'Tolerance for Female Genital '
#                                            'Mutilation is an awareness '
#                                            'campaign to end a harmful practice '
#                                            'that violates girls’ and women’s '
#                                            'rights.',
#                             'locations': 'All',
#                             'name': 'International Day of Zero Tolerance for '
#                                     'Female Genital Mutilation',
#                             'states': 'All',
#                             'type': ['United Nations observance']},
#                            {'country': {'id': 'us', 'name': 'United States'},
#                             'date': {'datetime': {'day': 7,
#                                                   'month': 2,
#                                                   'year': 2010},
#                                      'iso': '2010-02-07'},
#                             'description': 'The Super Bowl is the championship '
#                                            'game of the National Football '
#                                            'League (NFL) in the United States. '
#                                            'It is played every year in '
#                                            'February.',
#                             'locations': 'All',
#                             'name': 'Super Bowl',
#                             'states': 'All',
#                             'type': ['Sporting event']},
#                            {'country': {'id': 'us', 'name': 'United States'},
#                             'date': {'datetime': {'day': 11,
#                                                   'month': 2,
#                                                   'year': 2010},
#                                      'iso': '2010-02-11'},
#                             'description': 'Maha Shivaratri is a Hindu holiday '
#                                            'in the USA',
#                             'locations': 'All',
#                             'name': 'Maha Shivaratri',
#                             'states': 'All',
#                             'type': ['Hinduism']},
#                            {'country': {'id': 'us', 'name': 'United States'},
#                             'date': {'datetime': {'day': 12,
#                                                   'month': 2,
#                                                   'year': 2010},
#                                      'iso': '2010-02-12'},
#                             'description': 'Lincoln’s Birthday is observed in '
#                                            'the United States in honor of '
#                                            'Abraham Lincoln, who was the '
#                                            'nation’s 16th president and was '
#                                            'known as the Great Emancipator.',
#                             'locations': 'CT, IL, NJ, NY, MO',
#                             'name': "Lincoln's Birthday",
#                             'states': [{'abbrev': 'CT',
#                                         'exception': None,
#                                         'id': 9,
#                                         'iso': 'us-ct',
#                                         'name': 'Connecticut'},
#                                        {'abbrev': 'IL',
#                                         'exception': None,
#                                         'id': 16,
#                                         'iso': 'us-il',
#                                         'name': 'Illinois'},
#                                        {'abbrev': 'NJ',
#                                         'exception': None,
#                                         'id': 34,
#                                         'iso': 'us-nj',
#                                         'name': 'New Jersey'},
#                                        {'abbrev': 'NY',
#                                         'exception': None,
#                                         'id': 36,
#                                         'iso': 'us-ny',
#                                         'name': 'New York'},
#                                        {'abbrev': 'MO',
#                                         'exception': None,
#                                         'id': 29,
#                                         'iso': 'us-mo',
#                                         'name': 'Missouri'}],
#                             'type': ['Local holiday']},
#                            {'country': {'id': 'us', 'name': 'United States'},
#                             'date': {'datetime': {'day': 14,
#                                                   'month': 2,
#                                                   'year': 2010},
#                                      'iso': '2010-02-14'},
#                             'description': "Valentine's Day is an occasion to "
#                                            'celebrate romantic love.',
#                             'locations': 'All',
#                             'name': "Valentine's Day",
#                             'states': 'All',
#                             'type': ['Observance']},
#                            {'country': {'id': 'us', 'name': 'United States'},
#                             'date': {'datetime': {'day': 14,
#                                                   'month': 2,
#                                                   'year': 2010},
#                                      'iso': '2010-02-14'},
#                             'description': 'Statehood Day is a local '
#                                            'observance in the USA',
#                             'locations': 'AZ',
#                             'name': 'Statehood Day',
#                             'states': [{'abbrev': 'AZ',
#                                         'exception': None,
#                                         'id': 4,
#                                         'iso': 'us-az',
#                                         'name': 'Arizona'}],
#                             'type': ['Local observance']},
#                            {'country': {'id': 'us', 'name': 'United States'},
#                             'date': {'datetime': {'day': 14,
#                                                   'month': 2,
#                                                   'year': 2010},
#                                      'iso': '2010-02-14'},
#                             'description': 'Chinese New Year marks the first '
#                                            'day of the New Year in the Chinese '
#                                            'calendar.',
#                             'locations': 'All',
#                             'name': 'Chinese New Year',
#                             'states': 'All',
#                             'type': ['Observance']},
#                            {'country': {'id': 'us', 'name': 'United States'},
#                             'date': {'datetime': {'day': 15,
#                                                   'month': 2,
#                                                   'year': 2010},
#                                      'iso': '2010-02-15'},
#                             'description': "Washington's Birthday, or "
#                                            "Presidents' Day, honors the life "
#                                            'and work of the first president of '
#                                            'the United States, George '
#                                            'Washington.',
#                             'locations': 'All except DE, GA, IN, IA, KS, KY, '
#                                          'LA, NM, NC, RI, WI',
#                             'name': "Presidents' Day",
#                             'states': [{'abbrev': 'AL',
#                                         'exception': None,
#                                         'id': 1,
#                                         'iso': 'us-al',
#                                         'name': 'Alabama'},
#                                        {'abbrev': 'AK',
#                                         'exception': None,
#                                         'id': 2,
#                                         'iso': 'us-ak',
#                                         'name': 'Alaska'},
#                                        {'abbrev': 'AZ',
#                                         'exception': None,
#                                         'id': 4,
#                                         'iso': 'us-az',
#                                         'name': 'Arizona'},
#                                        {'abbrev': 'AR',
#                                         'exception': None,
#                                         'id': 5,
#                                         'iso': 'us-ar',
#                                         'name': 'Arkansas'},
#                                        {'abbrev': 'CA',
#                                         'exception': None,
#                                         'id': 7,
#                                         'iso': 'us-ca',
#                                         'name': 'California'},
#                                        {'abbrev': 'CO',
#                                         'exception': None,
#                                         'id': 8,
#                                         'iso': 'us-co',
#                                         'name': 'Colorado'},
#                                        {'abbrev': 'CT',
#                                         'exception': None,
#                                         'id': 9,
#                                         'iso': 'us-ct',
#                                         'name': 'Connecticut'},
#                                        {'abbrev': 'DC',
#                                         'exception': None,
#                                         'id': 11,
#                                         'iso': 'us-dc',
#                                         'name': 'District of Columbia'},
#                                        {'abbrev': 'FL',
#                                         'exception': None,
#                                         'id': 12,
#                                         'iso': 'us-fl',
#                                         'name': 'Florida'},
#                                        {'abbrev': 'HI',
#                                         'exception': None,
#                                         'id': 14,
#                                         'iso': 'us-hi',
#                                         'name': 'Hawaii'},
#                                        {'abbrev': 'ID',
#                                         'exception': None,
#                                         'id': 15,
#                                         'iso': 'us-id',
#                                         'name': 'Idaho'},
#                                        {'abbrev': 'IL',
#                                         'exception': None,
#                                         'id': 16,
#                                         'iso': 'us-il',
#                                         'name': 'Illinois'},
#                                        {'abbrev': 'ME',
#                                         'exception': None,
#                                         'id': 22,
#                                         'iso': 'us-me',
#                                         'name': 'Maine'},
#                                        {'abbrev': 'MD',
#                                         'exception': None,
#                                         'id': 24,
#                                         'iso': 'us-md',
#                                         'name': 'Maryland'},
#                                        {'abbrev': 'MA',
#                                         'exception': None,
#                                         'id': 25,
#                                         'iso': 'us-ma',
#                                         'name': 'Massachusetts'},
#                                        {'abbrev': 'MI',
#                                         'exception': None,
#                                         'id': 26,
#                                         'iso': 'us-mi',
#                                         'name': 'Michigan'},
#                                        {'abbrev': 'MN',
#                                         'exception': None,
#                                         'id': 27,
#                                         'iso': 'us-mn',
#                                         'name': 'Minnesota'},
#                                        {'abbrev': 'MS',
#                                         'exception': None,
#                                         'id': 28,
#                                         'iso': 'us-ms',
#                                         'name': 'Mississippi'},
#                                        {'abbrev': 'MO',
#                                         'exception': None,
#                                         'id': 29,
#                                         'iso': 'us-mo',
#                                         'name': 'Missouri'},
#                                        {'abbrev': 'MT',
#                                         'exception': None,
#                                         'id': 30,
#                                         'iso': 'us-mt',
#                                         'name': 'Montana'},
#                                        {'abbrev': 'NE',
#                                         'exception': None,
#                                         'id': 31,
#                                         'iso': 'us-ne',
#                                         'name': 'Nebraska'},
#                                        {'abbrev': 'NV',
#                                         'exception': None,
#                                         'id': 32,
#                                         'iso': 'us-nv',
#                                         'name': 'Nevada'},
#                                        {'abbrev': 'NH',
#                                         'exception': None,
#                                         'id': 33,
#                                         'iso': 'us-nh',
#                                         'name': 'New Hampshire'},
#                                        {'abbrev': 'NJ',
#                                         'exception': None,
#                                         'id': 34,
#                                         'iso': 'us-nj',
#                                         'name': 'New Jersey'},
#                                        {'abbrev': 'NY',
#                                         'exception': None,
#                                         'id': 36,
#                                         'iso': 'us-ny',
#                                         'name': 'New York'},
#                                        {'abbrev': 'ND',
#                                         'exception': None,
#                                         'id': 38,
#                                         'iso': 'us-nd',
#                                         'name': 'North Dakota'},
#                                        {'abbrev': 'OH',
#                                         'exception': None,
#                                         'id': 40,
#                                         'iso': 'us-oh',
#                                         'name': 'Ohio'},
#                                        {'abbrev': 'OK',
#                                         'exception': None,
#                                         'id': 41,
#                                         'iso': 'us-ok',
#                                         'name': 'Oklahoma'},
#                                        {'abbrev': 'OR',
#                                         'exception': None,
#                                         'id': 42,
#                                         'iso': 'us-or',
#                                         'name': 'Oregon'},
#                                        {'abbrev': 'PA',
#                                         'exception': None,
#                                         'id': 43,
#                                         'iso': 'us-pa',
#                                         'name': 'Pennsylvania'},
#                                        {'abbrev': 'SC',
#                                         'exception': None,
#                                         'id': 45,
#                                         'iso': 'us-sc',
#                                         'name': 'South Carolina'},
#                                        {'abbrev': 'SD',
#                                         'exception': None,
#                                         'id': 46,
#                                         'iso': 'us-sd',
#                                         'name': 'South Dakota'},
#                                        {'abbrev': 'TN',
#                                         'exception': None,
#                                         'id': 47,
#                                         'iso': 'us-tn',
#                                         'name': 'Tennessee'},
#                                        {'abbrev': 'TX',
#                                         'exception': None,
#                                         'id': 48,
#                                         'iso': 'us-tx',
#                                         'name': 'Texas'},
#                                        {'abbrev': 'UT',
#                                         'exception': None,
#                                         'id': 49,
#                                         'iso': 'us-ut',
#                                         'name': 'Utah'},
#                                        {'abbrev': 'VT',
#                                         'exception': None,
#                                         'id': 50,
#                                         'iso': 'us-vt',
#                                         'name': 'Vermont'},
#                                        {'abbrev': 'VA',
#                                         'exception': None,
#                                         'id': 52,
#                                         'iso': 'us-va',
#                                         'name': 'Virginia'},
#                                        {'abbrev': 'WA',
#                                         'exception': None,
#                                         'id': 53,
#                                         'iso': 'us-wa',
#                                         'name': 'Washington'},
#                                        {'abbrev': 'WV',
#                                         'exception': None,
#                                         'id': 54,
#                                         'iso': 'us-wv',
#                                         'name': 'West Virginia'},
#                                        {'abbrev': 'WY',
#                                         'exception': None,
#                                         'id': 56,
#                                         'iso': 'us-wy',
#                                         'name': 'Wyoming'}],
#                             'type': ['National holiday']},
#                            {'country': {'id': 'us', 'name': 'United States'},
#                             'date': {'datetime': {'day': 15,
#                                                   'month': 2,
#                                                   'year': 2010},
#                                      'iso': '2010-02-15'},
# ...
#                             'date': {'datetime': {'day': 13,
#                                                   'month': 12,
#                                                   'year': 2010},
#                                      'iso': '2010-12-13'},
#                             'description': 'National Guard Birthday is a '
#                                            'observance in the USA',
#                             'locations': 'All',
#                             'name': 'National Guard Birthday',
#                             'states': 'All',
#                             'type': ['Observance']},
#                            {'country': {'id': 'us', 'name': 'United States'},
#                             'date': {'datetime': {'day': 15,
#                                                   'month': 12,
#                                                   'year': 2010},
#                                      'iso': '2010-12-15'},
#                             'description': 'Bill of Rights Day is a observance '
#                                            'in the USA',
#                             'locations': 'All',
#                             'name': 'Bill of Rights Day',
#                             'states': 'All',
#                             'type': ['Observance']},
#                            {'country': {'id': 'us', 'name': 'United States'},
#                             'date': {'datetime': {'day': 17,
#                                                   'month': 12,
#                                                   'year': 2010},
#                                      'iso': '2010-12-17'},
#                             'description': 'December 17 marks Pan American '
#                                            'Aviation Day, which is annually '
#                                            'observed in the United States.',
#                             'locations': 'All',
#                             'name': 'Pan American Aviation Day',
#                             'states': 'All',
#                             'type': ['Observance']},
#                            {'country': {'id': 'us', 'name': 'United States'},
#                             'date': {'datetime': {'day': 17,
#                                                   'month': 12,
#                                                   'year': 2010},
#                                      'iso': '2010-12-17'},
#                             'description': 'The Wright Brothers Day is '
#                                            'annually celebrated in the United '
#                                            'States on December 17 to '
#                                            'commemorate the historic flight '
#                                            'made by Orville and Wilbur Wright '
#                                            'on that date in 1903.',
#                             'locations': 'All',
#                             'name': 'Wright Brothers Day',
#                             'states': 'All',
#                             'type': ['Observance']},
#                            {'country': {'id': 'us', 'name': 'United States'},
#                             'date': {'datetime': {'day': 18,
#                                                   'month': 12,
#                                                   'year': 2010},
#                                      'iso': '2010-12-18'},
#                             'description': 'The United Nations (UN) '
#                                            'International Migrants Day is '
#                                            'celebrated on December 18 each '
#                                            'year.',
#                             'locations': 'All',
#                             'name': 'International Migrants Day',
#                             'states': 'All',
#                             'type': ['United Nations observance']},
#                            {'country': {'id': 'us', 'name': 'United States'},
#                             'date': {'datetime': {'day': 19,
#                                                   'month': 12,
#                                                   'year': 2010},
#                                      'iso': '2010-12-19'},
#                             'description': 'The United Nations Day for '
#                                            'South-South Cooperation is '
#                                            'observed on September 12 each '
#                                            'year.',
#                             'locations': 'All',
#                             'name': 'International Day for South-South '
#                                     'Cooperation',
#                             'states': 'All',
#                             'type': ['United Nations observance']},
#                            {'country': {'id': 'us', 'name': 'United States'},
#                             'date': {'datetime': {'day': 20,
#                                                   'month': 12,
#                                                   'year': 2010},
#                                      'iso': '2010-12-20'},
#                             'description': "The United Nations' (UN) "
#                                            'International Human Solidarity Day '
#                                            'is celebrated on December 20 each '
#                                            'year to raise public awareness on '
#                                            'the importance of solidarity in '
#                                            'fighting poverty.',
#                             'locations': 'All',
#                             'name': 'International Human Solidarity Day',
#                             'states': 'All',
#                             'type': ['United Nations observance']},
#                            {'country': {'id': 'us', 'name': 'United States'},
#                             'date': {'datetime': {'day': 21,
#                                                   'hour': 18,
#                                                   'minute': 38,
#                                                   'month': 12,
#                                                   'second': 27,
#                                                   'year': 2010},
#                                      'iso': '2010-12-21T18:38:27-05:00',
#                                      'timezone': {'offset': '-05:00',
#                                                   'zoneabb': 'EST',
#                                                   'zonedst': 0,
#                                                   'zoneoffset': -18000,
#                                                   'zonetotaloffset': -18000}},
#                             'description': 'December Solstice in the USA (New '
#                                            'York)',
#                             'locations': 'All',
#                             'name': 'December Solstice',
#                             'states': 'All',
#                             'type': ['Season']},
#                            {'country': {'id': 'us', 'name': 'United States'},
#                             'date': {'datetime': {'day': 23,
#                                                   'month': 12,
#                                                   'year': 2010},
#                                      'iso': '2010-12-23'},
#                             'description': "Washington's Birthday, or "
#                                            "Presidents' Day, honors the life "
#                                            'and work of the first president of '
#                                            'the United States, George '
#                                            'Washington.',
#                             'locations': 'IN',
#                             'name': "Washington's Birthday",
#                             'states': [{'abbrev': 'IN',
#                                         'exception': None,
#                                         'id': 17,
#                                         'iso': 'us-in',
#                                         'name': 'Indiana'}],
#                             'type': ['Local holiday']},
#                            {'country': {'id': 'us', 'name': 'United States'},
#                             'date': {'datetime': {'day': 24,
#                                                   'month': 12,
#                                                   'year': 2010},
#                                      'iso': '2010-12-24'},
#                             'description': 'Christmas Day celebrates Jesus '
#                                            "Christ's birth.",
#                             'locations': 'All',
#                             'name': 'Day off for Christmas Day',
#                             'states': 'All',
#                             'type': ['National holiday', 'Christian']},
#                            {'country': {'id': 'us', 'name': 'United States'},
#                             'date': {'datetime': {'day': 24,
#                                                   'month': 12,
#                                                   'year': 2010},
#                                      'iso': '2010-12-24'},
#                             'description': 'Christmas Eve in the United States '
#                                            'is on December 24 each year.',
#                             'locations': 'All',
#                             'name': 'Christmas Eve',
#                             'states': 'All',
#                             'type': ['Observance', 'Christian']},
#                            {'country': {'id': 'us', 'name': 'United States'},
#                             'date': {'datetime': {'day': 24,
#                                                   'month': 12,
#                                                   'year': 2010},
#                                      'iso': '2010-12-24'},
#                             'description': 'Christmas Eve in the United States '
#                                            'is on December 24 each year.',
#                             'locations': 'TX',
#                             'name': 'Christmas Eve',
#                             'states': [{'abbrev': 'TX',
#                                         'exception': None,
#                                         'id': 48,
#                                         'iso': 'us-tx',
#                                         'name': 'Texas'}],
#                             'type': ['Local holiday']},
#                            {'country': {'id': 'us', 'name': 'United States'},
#                             'date': {'datetime': {'day': 25,
#                                                   'month': 12,
#                                                   'year': 2010},
#                                      'iso': '2010-12-25'},
#                             'description': 'Christmas Day celebrates Jesus '
#                                            "Christ's birth.",
#                             'locations': 'All',
#                             'name': 'Christmas Day',
#                             'states': 'All',
#                             'type': ['National holiday', 'Christian']},
#                            {'country': {'id': 'us', 'name': 'United States'},
#                             'date': {'datetime': {'day': 26,
#                                                   'month': 12,
#                                                   'year': 2010},
#                                      'iso': '2010-12-26'},
#                             'description': 'Kwanzaa is a week-long holiday '
#                                            'honoring the culture and '
#                                            'traditions of African people and '
#                                            'their descendants worldwide, '
#                                            'especially in the United States.',
#                             'locations': 'All',
#                             'name': 'Kwanzaa (first day)',
#                             'states': 'All',
#                             'type': ['Observance']},
#                            {'country': {'id': 'us', 'name': 'United States'},
#                             'date': {'datetime': {'day': 26,
#                                                   'month': 12,
#                                                   'year': 2010},
#                                      'iso': '2010-12-26'},
#                             'description': 'Some states in the United States '
#                                            'observe the Day after Christmas '
#                                            'Day as a public holiday.',
#                             'locations': 'TX',
#                             'name': 'Day After Christmas Day',
#                             'states': [{'abbrev': 'TX',
#                                         'exception': None,
#                                         'id': 48,
#                                         'iso': 'us-tx',
#                                         'name': 'Texas'}],
#                             'type': ['Local holiday']},
#                            {'country': {'id': 'us', 'name': 'United States'},
#                             'date': {'datetime': {'day': 31,
#                                                   'month': 12,
#                                                   'year': 2010},
#                                      'iso': '2010-12-31'},
#                             'description': "New Year's Day is the first day of "
#                                            'the Gregorian calendar, which is '
#                                            'widely used in many countries such '
#                                            'as the USA.',
#                             'locations': 'All',
#                             'name': "Day off for New Year's Day",
#                             'states': 'All',
#                             'type': ['National holiday']},
#                            {'country': {'id': 'us', 'name': 'United States'},
#                             'date': {'datetime': {'day': 31,
#                                                   'month': 12,
#                                                   'year': 2010},
#                                      'iso': '2010-12-31'},
#                             'description': "New Year's Eve is the last day of "
#                                            'the year in the Gregorian '
#                                            'calendar. Many parties to welcome '
#                                            'the New Year are held in in the '
#                                            "United States on New Year's Eve.",
#                             'locations': 'All',
#                             'name': "New Year's Eve",
#                             'states': 'All',
#                             'type': ['Observance']}]}}
#    Unnamed: 0  Store  Dept        Date  Weekly_Sales  IsHoliday  \
# 0           0      1     1  2010-02-05      24924.50      False
# 1      277665     29     5  2010-02-05      15552.08      False
# 2      277808     29     6  2010-02-05       3200.22      False
# 3      277951     29     7  2010-02-05      10820.05      False
# 4      278094     29     8  2010-02-05      20055.64      False
#
#    Temperature F  Fuel_Price         CPI  Unemployment Type    Size  Week  \
# 0          42.31       2.572  211.096358         8.106    A  151315     5
# 1          24.36       2.788  131.527903        10.064    B   93638     5
# 2          24.36       2.788  131.527903        10.064    B   93638     5
# 3          24.36       2.788  131.527903        10.064    B   93638     5
# 4          24.36       2.788  131.527903        10.064    B   93638     5
#
#    Year  Temperature C Start of Week Holiday Name
# 0  2010       5.727778    2010-01-30   No Holiday
# 1  2010      -4.244444    2010-01-30   No Holiday
# 2  2010      -4.244444    2010-01-30   No Holiday
# 3  2010      -4.244444    2010-01-30   No Holiday
# 4  2010      -4.244444    2010-01-30   No Holiday

# %%
# Display preview of dataframe
walmart_clean.head()
# Out:
#    Unnamed: 0  Store  Dept        Date  Weekly_Sales  IsHoliday  \
# 0           0      1     1  2010-02-05      24924.50      False
# 1      277665     29     5  2010-02-05      15552.08      False
# 2      277808     29     6  2010-02-05       3200.22      False
# 3      277951     29     7  2010-02-05      10820.05      False
# 4      278094     29     8  2010-02-05      20055.64      False
#
#    Temperature F  Fuel_Price         CPI  Unemployment Type    Size  Week  \
# 0          42.31       2.572  211.096358         8.106    A  151315     5
# 1          24.36       2.788  131.527903        10.064    B   93638     5
# 2          24.36       2.788  131.527903        10.064    B   93638     5
# 3          24.36       2.788  131.527903        10.064    B   93638     5
# 4          24.36       2.788  131.527903        10.064    B   93638     5
#
#    Year  Temperature C Start of Week Holiday Name
# 0  2010       5.727778    2010-01-30   No Holiday
# 1  2010      -4.244444    2010-01-30   No Holiday
# 2  2010      -4.244444    2010-01-30   No Holiday
# 3  2010      -4.244444    2010-01-30   No Holiday
# 4  2010      -4.244444    2010-01-30   No Holiday

# %%
# Create a list identifying whether that week is a Holiday or No Holiday
is_holiday = []

for holiday in walmart_clean['Holiday Name']:
    
    if holiday == 'No Holiday':
        
        is_holiday.append("No Holiday")
    
    else:
        
        is_holiday.append("Holiday")
        
# Add new column equal to the list created        
walmart_clean['Is Holiday'] = is_holiday

# Group by Is Holiday
walmart_ttl = pd.DataFrame(walmart_clean.groupby('Is Holiday')['Weekly_Sales'].sum())

# Caclulate Percentage
walmart_ttl['Percentage %'] = walmart_ttl['Weekly_Sales']/walmart_ttl['Weekly_Sales'].sum()

# Format Weekly Sales and Percentage
walmart_ttl['Weekly_Sales'] = pd.DataFrame(walmart_ttl['Weekly_Sales'].map("${:,.2f}".format))
walmart_ttl['Percentage %'] = pd.DataFrame(walmart_ttl['Percentage %'].map("{:.0%}".format))

#Export
outputfile = "Project 1/Summary/total_percent.csv"
walmart_ttl.to_csv(outputfile, header = True)

# Add title to Dataframe
walmart_ttl = walmart_ttl.style.set_caption("Total Holiday Weekly Sales and Percentages").set_table_styles([{
    'selector': 'caption',
    'props': [('color', 'black'), ('font-size', '13px'), ('font-weight', 'bold')]
}])

# Display dataframe
walmart_ttl

## The 4 major holidays account for about 8% of total sales, this is not very high as the 4 holidays will account for
## 4 out of the 52 weeks in a year which is also a little less than 8% (4/52 = 7.69%)
# Out:
# <style  type="text/css" >
#     #T_19e63254_2144_11eb_9c49_181deafdb758 caption {
#           color: black;
#           font-size: 13px;
#           font-weight: bold;
#     }</style><table id="T_19e63254_2144_11eb_9c49_181deafdb758" ><caption>Total Holiday Weekly Sales and Percentages</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Weekly_Sales</th>        <th class="col_heading level0 col1" >Percentage %</th>    </tr>    <tr>        <th class="index_name level0" >Is Holiday</th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_19e63254_2144_11eb_9c49_181deafdb758level0_row0" class="row_heading level0 row0" >Holiday</th>
#                         <td id="T_19e63254_2144_11eb_9c49_181deafdb758row0_col0" class="data row0 col0" >$534,564,028.89</td>
#                         <td id="T_19e63254_2144_11eb_9c49_181deafdb758row0_col1" class="data row0 col1" >8%</td>
#             </tr>
#             <tr>
#                         <th id="T_19e63254_2144_11eb_9c49_181deafdb758level0_row1" class="row_heading level0 row1" >No Holiday</th>
#                         <td id="T_19e63254_2144_11eb_9c49_181deafdb758row1_col0" class="data row1 col0" >$6,202,654,958.22</td>
#                         <td id="T_19e63254_2144_11eb_9c49_181deafdb758row1_col1" class="data row1 col1" >92%</td>
#             </tr>
#     </tbody></table>

# %%
# Mainly grouping by Date and Store, adding Holiday Name and Is Holiday to get the values
walmart_groupby = walmart_clean.groupby(['Date', 'Store','Holiday Name','Is Holiday'])

# Aggregate across our question variables, set Dataframe and reset index
walmart_holiday = pd.DataFrame(walmart_groupby.agg({'Weekly_Sales': 'sum', 
                                                    'Temperature': 'mean',
                                                   'CPI': 'mean',
                                                   'Unemployment': 'mean',
                                                   'Fuel_Price': 'mean'}).reset_index())

# Display preview of dataframe
walmart_holiday.head()
# Out:
#          Date  Store Holiday Name  Is Holiday  Weekly_Sales  Temperature  \
# 0  2010-02-05      1   No Holiday  No Holiday    1643690.90            6
# 1  2010-02-05      2   No Holiday  No Holiday    2136989.46            5
# 2  2010-02-05      3   No Holiday  No Holiday     461622.22            8
# 3  2010-02-05      4   No Holiday  No Holiday    2135143.87            7
# 4  2010-02-05      5   No Holiday  No Holiday     317173.10            4
#
#       CPI  Unemployment  Fuel_Price
# 0  211.10         8.106        2.57
# 1  210.75         8.324        2.57
# 2  214.42         7.368        2.57
# 3  126.44         8.623        2.60
# 4  211.65         6.566        2.57

# %%
# Examining the weeks that have the highest Weekly Sales

walmart_holiday.sort_values(by= 'Weekly_Sales', ascending = False).head()

## Christmas has the top 3 highest weekly_sales out the 3 years in Walmart
# Out:
#             Date  Store Holiday Name  Is Holiday  Weekly_Sales  Temperature  \
# 2083  2010-12-24     14    Christmas     Holiday    3818686.45           -1
# 2089  2010-12-24     20    Christmas     Holiday    3766687.43           -4
# 2079  2010-12-24     10    Christmas     Holiday    3749057.69           14
# 4413  2011-12-23      4   No Holiday  No Holiday    3676388.98            2
# 2082  2010-12-24     13    Christmas     Holiday    3595903.20            2
#
#          CPI  Unemployment  Fuel_Price
# 2083  182.54         8.724        3.14
# 2089  204.64         7.484        3.14
# 2079  126.98         9.003        3.24
# 4413  129.98         5.143        3.10
# 2082  126.98         7.795        2.85

# %%
# Examining the weeks that have the lowest Weekly Sales

walmart_holiday.sort_values(by= 'Weekly_Sales', ascending = True).head()

## During the month of February had lowest/no sales during the 4 years
# Out:
#             Date  Store Holiday Name  Is Holiday  Weekly_Sales  Temperature  \
# 7604  2013-04-26     45   No Holiday  No Holiday           0.0           10
# 7008  2013-01-25     34   No Holiday  No Holiday           0.0            7
# 7009  2013-01-25     35   No Holiday  No Holiday           0.0           -3
# 7010  2013-01-25     36   No Holiday  No Holiday           0.0           14
# 7011  2013-01-25     37   No Holiday  No Holiday           0.0           14
#
#          CPI  Unemployment  Fuel_Price
# 7604  193.59         8.335        3.62
# 7008  132.09         8.934        3.22
# 7009  142.80         8.600        3.58
# 7010  222.90         6.266        3.24
# 7011  222.90         6.266        3.23

# %%
# (1) ************************************** TEMPERATURE **************************************
# (1A) What effect does temperature have on weekly sales? 
# Hypothesis: Expecting extreme weather temperature to have lower sales

# Create bin and label in dataframe, temperature increment of 10 degrees
bins = [ min(walmart_holiday['Temperature']) - 2, -10, -1, 9, 19, 29, max(walmart_holiday['Temperature']) + 2 ]
labels = [ "<-10°C", "-10°C to -1°C", "0°C to 9°C", "10°C to 19°C","20°C to 29°C", "≥30°C"]

# Add bin/label Column
walmart_holiday['Temp Category'] = pd.cut(walmart_holiday['Temperature'], bins, labels = labels)

# Display preview of dataframe
walmart_holiday.head()
# Out:
#          Date  Store Holiday Name  Is Holiday  Weekly_Sales  Temperature  \
# 0  2010-02-05      1   No Holiday  No Holiday    1643690.90            6
# 1  2010-02-05      2   No Holiday  No Holiday    2136989.46            5
# 2  2010-02-05      3   No Holiday  No Holiday     461622.22            8
# 3  2010-02-05      4   No Holiday  No Holiday    2135143.87            7
# 4  2010-02-05      5   No Holiday  No Holiday     317173.10            4
#
#       CPI  Unemployment  Fuel_Price Temp Category
# 0  211.10         8.106        2.57    0°C to 9°C
# 1  210.75         8.324        2.57    0°C to 9°C
# 2  214.42         7.368        2.57    0°C to 9°C
# 3  126.44         8.623        2.60    0°C to 9°C
# 4  211.65         6.566        2.57    0°C to 9°C

# %%
# (1A) TEMPERATURE CONT.

# Check Average Weekly Sale for Temperature Category
temp = pd.DataFrame(walmart_holiday.groupby('Temp Category')['Weekly_Sales'].mean())

# Format Weekly Sales
temp['Weekly_Sales'] = temp['Weekly_Sales'].map("${:,.2f}".format)

# Export File
outputfile = "Project 1/Temperature/temp_avg.csv"
temp.to_csv(outputfile, header = True)

# Add title
temp = temp.style.set_caption("Temperature vs. Average Weekly Sales").set_table_styles([{
    'selector': 'caption',
    'props': [('color', 'black'), ('font-size', '13px'), ('font-weight', 'bold')]
}])

# Display dataframe
temp

## Table suggests that weekly sales is a lot lower when the temperature is cold (< -10°C)
## When temperature is warm 20-29, average weekly sales is the highest
# Out:
# <style  type="text/css" >
#     #T_1a23a79a_2144_11eb_9455_181deafdb758 caption {
#           color: black;
#           font-size: 13px;
#           font-weight: bold;
#     }</style><table id="T_1a23a79a_2144_11eb_9455_181deafdb758" ><caption>Temperature vs. Average Weekly Sales</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Weekly_Sales</th>    </tr>    <tr>        <th class="index_name level0" >Temp Category</th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_1a23a79a_2144_11eb_9455_181deafdb758level0_row0" class="row_heading level0 row0" ><-10°C</th>
#                         <td id="T_1a23a79a_2144_11eb_9455_181deafdb758row0_col0" class="data row0 col0" >$402,754.59</td>
#             </tr>
#             <tr>
#                         <th id="T_1a23a79a_2144_11eb_9455_181deafdb758level0_row1" class="row_heading level0 row1" >-10°C to -1°C</th>
#                         <td id="T_1a23a79a_2144_11eb_9455_181deafdb758row1_col0" class="data row1 col0" >$766,037.81</td>
#             </tr>
#             <tr>
#                         <th id="T_1a23a79a_2144_11eb_9455_181deafdb758level0_row2" class="row_heading level0 row2" >0°C to 9°C</th>
#                         <td id="T_1a23a79a_2144_11eb_9455_181deafdb758row2_col0" class="data row2 col0" >$818,247.46</td>
#             </tr>
#             <tr>
#                         <th id="T_1a23a79a_2144_11eb_9455_181deafdb758level0_row3" class="row_heading level0 row3" >10°C to 19°C</th>
#                         <td id="T_1a23a79a_2144_11eb_9455_181deafdb758row3_col0" class="data row3 col0" >$855,314.94</td>
#             </tr>
#             <tr>
#                         <th id="T_1a23a79a_2144_11eb_9455_181deafdb758level0_row4" class="row_heading level0 row4" >20°C to 29°C</th>
#                         <td id="T_1a23a79a_2144_11eb_9455_181deafdb758row4_col0" class="data row4 col0" >$1,017,458.08</td>
#             </tr>
#             <tr>
#                         <th id="T_1a23a79a_2144_11eb_9455_181deafdb758level0_row5" class="row_heading level0 row5" >≥30°C</th>
#                         <td id="T_1a23a79a_2144_11eb_9455_181deafdb758row5_col0" class="data row5 col0" >$894,782.07</td>
#             </tr>
#     </tbody></table>

# %%
# (1A) TEMPERATURE CONT.

#Which temperature category has the highest total weekly sales
temp_ttl = pd.DataFrame(walmart_holiday.groupby("Temp Category")['Weekly_Sales'].sum())

# Calculate
temp_ttl['Percentage %'] = temp_ttl['Weekly_Sales']/temp_ttl['Weekly_Sales'].sum()

# Calculate Count
temp_ttl['Count'] = walmart_holiday.groupby("Temp Category")['Weekly_Sales'].count()

# Calculate Count Total
temp_ttl['Count Percentage %'] = temp_ttl['Count']/temp_ttl['Count'].sum()

# Format Weekly Sales
temp_ttl['Weekly_Sales'] = temp_ttl['Weekly_Sales'].map("${:,.2f}".format)
temp_ttl['Percentage %'] = temp_ttl['Percentage %'].map("{:.1%}".format)
temp_ttl['Count Percentage %'] = temp_ttl['Count Percentage %'].map("{:.1%}".format)
                        
# Export file
outputfile = "Project 1/Temperature/temp_ttl.csv"
temp_ttl.to_csv(outputfile, header = True)

# Add title
temp_ttl = temp_ttl.style.set_caption("Temperature vs. Total Weekly Sales").set_table_styles([{
    'selector': 'caption',
    'props': [('color', 'black'), ('font-size', '13px'), ('font-weight', 'bold')]
}])
                        
# Display dataframe
temp_ttl

## Table suggests that weekly sales is a lot lower when the temperature is cold (< -10°C)
## When temperature is warm 20-29, total weekly sales is the highest accounting for 1/3 of total revenue
# Out:
# <style  type="text/css" >
#     #T_1a35ec08_2144_11eb_ace3_181deafdb758 caption {
#           color: black;
#           font-size: 13px;
#           font-weight: bold;
#     }</style><table id="T_1a35ec08_2144_11eb_ace3_181deafdb758" ><caption>Temperature vs. Total Weekly Sales</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Weekly_Sales</th>        <th class="col_heading level0 col1" >Percentage %</th>        <th class="col_heading level0 col2" >Count</th>        <th class="col_heading level0 col3" >Count Percentage %</th>    </tr>    <tr>        <th class="index_name level0" >Temp Category</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_1a35ec08_2144_11eb_ace3_181deafdb758level0_row0" class="row_heading level0 row0" ><-10°C</th>
#                         <td id="T_1a35ec08_2144_11eb_ace3_181deafdb758row0_col0" class="data row0 col0" >$23,762,520.52</td>
#                         <td id="T_1a35ec08_2144_11eb_ace3_181deafdb758row0_col1" class="data row0 col1" >0.4%</td>
#                         <td id="T_1a35ec08_2144_11eb_ace3_181deafdb758row0_col2" class="data row0 col2" >59</td>
#                         <td id="T_1a35ec08_2144_11eb_ace3_181deafdb758row0_col3" class="data row0 col3" >0.8%</td>
#             </tr>
#             <tr>
#                         <th id="T_1a35ec08_2144_11eb_ace3_181deafdb758level0_row1" class="row_heading level0 row1" >-10°C to -1°C</th>
#                         <td id="T_1a35ec08_2144_11eb_ace3_181deafdb758row1_col0" class="data row1 col0" >$456,558,533.86</td>
#                         <td id="T_1a35ec08_2144_11eb_ace3_181deafdb758row1_col1" class="data row1 col1" >6.8%</td>
#                         <td id="T_1a35ec08_2144_11eb_ace3_181deafdb758row1_col2" class="data row1 col2" >596</td>
#                         <td id="T_1a35ec08_2144_11eb_ace3_181deafdb758row1_col3" class="data row1 col3" >7.8%</td>
#             </tr>
#             <tr>
#                         <th id="T_1a35ec08_2144_11eb_ace3_181deafdb758level0_row2" class="row_heading level0 row2" >0°C to 9°C</th>
#                         <td id="T_1a35ec08_2144_11eb_ace3_181deafdb758row2_col0" class="data row2 col0" >$1,467,117,694.38</td>
#                         <td id="T_1a35ec08_2144_11eb_ace3_181deafdb758row2_col1" class="data row2 col1" >21.8%</td>
#                         <td id="T_1a35ec08_2144_11eb_ace3_181deafdb758row2_col2" class="data row2 col2" >1793</td>
#                         <td id="T_1a35ec08_2144_11eb_ace3_181deafdb758row2_col3" class="data row2 col3" >23.6%</td>
#             </tr>
#             <tr>
#                         <th id="T_1a35ec08_2144_11eb_ace3_181deafdb758level0_row3" class="row_heading level0 row3" >10°C to 19°C</th>
#                         <td id="T_1a35ec08_2144_11eb_ace3_181deafdb758row3_col0" class="data row3 col0" >$2,063,874,961.30</td>
#                         <td id="T_1a35ec08_2144_11eb_ace3_181deafdb758row3_col1" class="data row3 col1" >30.6%</td>
#                         <td id="T_1a35ec08_2144_11eb_ace3_181deafdb758row3_col2" class="data row3 col2" >2413</td>
#                         <td id="T_1a35ec08_2144_11eb_ace3_181deafdb758row3_col3" class="data row3 col3" >31.7%</td>
#             </tr>
#             <tr>
#                         <th id="T_1a35ec08_2144_11eb_ace3_181deafdb758level0_row4" class="row_heading level0 row4" >20°C to 29°C</th>
#                         <td id="T_1a35ec08_2144_11eb_ace3_181deafdb758row4_col0" class="data row4 col0" >$2,244,512,522.11</td>
#                         <td id="T_1a35ec08_2144_11eb_ace3_181deafdb758row4_col1" class="data row4 col1" >33.3%</td>
#                         <td id="T_1a35ec08_2144_11eb_ace3_181deafdb758row4_col2" class="data row4 col2" >2206</td>
#                         <td id="T_1a35ec08_2144_11eb_ace3_181deafdb758row4_col3" class="data row4 col3" >29.0%</td>
#             </tr>
#             <tr>
#                         <th id="T_1a35ec08_2144_11eb_ace3_181deafdb758level0_row5" class="row_heading level0 row5" >≥30°C</th>
#                         <td id="T_1a35ec08_2144_11eb_ace3_181deafdb758row5_col0" class="data row5 col0" >$481,392,754.94</td>
#                         <td id="T_1a35ec08_2144_11eb_ace3_181deafdb758row5_col1" class="data row5 col1" >7.1%</td>
#                         <td id="T_1a35ec08_2144_11eb_ace3_181deafdb758row5_col2" class="data row5 col2" >538</td>
#                         <td id="T_1a35ec08_2144_11eb_ace3_181deafdb758row5_col3" class="data row5 col3" >7.1%</td>
#             </tr>
#     </tbody></table>

# %%
# (1A) TEMPERATURE CONT.

# Linear Regression
(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(walmart_holiday['Temperature'], walmart_holiday["Weekly_Sales"])

# Calculate x-values and regression values
x_values = walmart_holiday['Temperature']
y_values = slope*x_values + intercept

# Create linear regression equation
line_eq = 'y = ' + str(round(slope,2)) + "x + " + str(round(intercept,2))

print(line_eq, round(rvalue,2))

## (1) Equation suggests a positive relationship between Weekly Sales and Temperature
## implying an increase in temperature is correlated to weekly sales
## (2) R-Value is very close to 0 which suggest a very bad fit to the data
## Linear regression is not a good model for the two variables
# Out:
# y = 7889.54x + 770623.02 0.13

# %%
# (1B) TEMPERATURE HOLIDAY

# (1B) What effect does temperature have on holiday weekly sales? 
# Hypothesis: Expecting extreme weather temperature to still have lower sales during the holiday

# Check Average Weekly Sale for Temperature Category if it's a holiday or not
temp_is = pd.DataFrame(walmart_holiday.groupby(["Is Holiday", "Temp Category"])["Weekly_Sales"].mean())

# Format Weekly Sales
temp_is['Weekly_Sales'] = temp_is['Weekly_Sales'].map("${:,.2f}".format)

# Export file
outputfile = "Project 1/Temperature/temp_avg_is.csv"
temp_is.to_csv(outputfile, header = True)

# Add title
temp_is = temp_is.style.set_caption("Temperature vs. Average Holiday/Regular Weekly Sales").set_table_styles([{
    'selector': 'caption',
   'props': [('color', 'black'), ('font-size', '13px'), ('font-weight', 'bold')]
}])

# Display dataframe
temp_is

## Surprisingly when it's the holiday and cold there's a bit more spending than expected until we get to -10,
## possibly explanation is Christmas
# Out:
# <style  type="text/css" >
#     #T_1a4f121d_2144_11eb_a5ec_181deafdb758 caption {
#           color: black;
#           font-size: 13px;
#           font-weight: bold;
#     }</style><table id="T_1a4f121d_2144_11eb_a5ec_181deafdb758" ><caption>Temperature vs. Average Holiday/Regular Weekly Sales</caption><thead>    <tr>        <th class="blank" ></th>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Weekly_Sales</th>    </tr>    <tr>        <th class="index_name level0" >Is Holiday</th>        <th class="index_name level1" >Temp Category</th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_1a4f121d_2144_11eb_a5ec_181deafdb758level0_row0" class="row_heading level0 row0" rowspan=6>Holiday</th>
#                         <th id="T_1a4f121d_2144_11eb_a5ec_181deafdb758level1_row0" class="row_heading level1 row0" ><-10°C</th>
#                         <td id="T_1a4f121d_2144_11eb_a5ec_181deafdb758row0_col0" class="data row0 col0" >$234,411.78</td>
#             </tr>
#             <tr>
#                                 <th id="T_1a4f121d_2144_11eb_a5ec_181deafdb758level1_row1" class="row_heading level1 row1" >-10°C to -1°C</th>
#                         <td id="T_1a4f121d_2144_11eb_a5ec_181deafdb758row1_col0" class="data row1 col0" >$913,252.00</td>
#             </tr>
#             <tr>
#                                 <th id="T_1a4f121d_2144_11eb_a5ec_181deafdb758level1_row2" class="row_heading level1 row2" >0°C to 9°C</th>
#                         <td id="T_1a4f121d_2144_11eb_a5ec_181deafdb758row2_col0" class="data row2 col0" >$870,873.07</td>
#             </tr>
#             <tr>
#                                 <th id="T_1a4f121d_2144_11eb_a5ec_181deafdb758level1_row3" class="row_heading level1 row3" >10°C to 19°C</th>
#                         <td id="T_1a4f121d_2144_11eb_a5ec_181deafdb758row3_col0" class="data row3 col0" >$853,253.02</td>
#             </tr>
#             <tr>
#                                 <th id="T_1a4f121d_2144_11eb_a5ec_181deafdb758level1_row4" class="row_heading level1 row4" >20°C to 29°C</th>
#                         <td id="T_1a4f121d_2144_11eb_a5ec_181deafdb758row4_col0" class="data row4 col0" >$1,161,111.59</td>
#             </tr>
#             <tr>
#                                 <th id="T_1a4f121d_2144_11eb_a5ec_181deafdb758level1_row5" class="row_heading level1 row5" >≥30°C</th>
#                         <td id="T_1a4f121d_2144_11eb_a5ec_181deafdb758row5_col0" class="data row5 col0" >$931,488.78</td>
#             </tr>
#             <tr>
#                         <th id="T_1a4f121d_2144_11eb_a5ec_181deafdb758level0_row6" class="row_heading level0 row6" rowspan=6>No Holiday</th>
#                         <th id="T_1a4f121d_2144_11eb_a5ec_181deafdb758level1_row6" class="row_heading level1 row6" ><-10°C</th>
#                         <td id="T_1a4f121d_2144_11eb_a5ec_181deafdb758row6_col0" class="data row6 col0" >$450,329.73</td>
#             </tr>
#             <tr>
#                                 <th id="T_1a4f121d_2144_11eb_a5ec_181deafdb758level1_row7" class="row_heading level1 row7" >-10°C to -1°C</th>
#                         <td id="T_1a4f121d_2144_11eb_a5ec_181deafdb758row7_col0" class="data row7 col0" >$736,357.53</td>
#             </tr>
#             <tr>
#                                 <th id="T_1a4f121d_2144_11eb_a5ec_181deafdb758level1_row8" class="row_heading level1 row8" >0°C to 9°C</th>
#                         <td id="T_1a4f121d_2144_11eb_a5ec_181deafdb758row8_col0" class="data row8 col0" >$810,925.34</td>
#             </tr>
#             <tr>
#                                 <th id="T_1a4f121d_2144_11eb_a5ec_181deafdb758level1_row9" class="row_heading level1 row9" >10°C to 19°C</th>
#                         <td id="T_1a4f121d_2144_11eb_a5ec_181deafdb758row9_col0" class="data row9 col0" >$855,422.85</td>
#             </tr>
#             <tr>
#                                 <th id="T_1a4f121d_2144_11eb_a5ec_181deafdb758level1_row10" class="row_heading level1 row10" >20°C to 29°C</th>
#                         <td id="T_1a4f121d_2144_11eb_a5ec_181deafdb758row10_col0" class="data row10 col0" >$1,010,565.44</td>
#             </tr>
#             <tr>
#                                 <th id="T_1a4f121d_2144_11eb_a5ec_181deafdb758level1_row11" class="row_heading level1 row11" >≥30°C</th>
#                         <td id="T_1a4f121d_2144_11eb_a5ec_181deafdb758row11_col0" class="data row11 col0" >$892,460.70</td>
#             </tr>
#     </tbody></table>

# %%
# (1B) TEMPERATURE HOLIDAY CONT.

#Take Subset Dataframe of Holiday and Not Holiday
not_holiday = walmart_holiday.loc[walmart_holiday['Is Holiday'] == 'No Holiday', :]
holiday = walmart_holiday.loc[walmart_holiday['Is Holiday'] == 'Holiday', :]

#Calculate linear regression coefficients
(slope_h, intercept_h, rvalue_h, pvalue_h, stderr_h) = stats.linregress(holiday['Temperature'], holiday["Weekly_Sales"])
(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(not_holiday['Temperature'], not_holiday["Weekly_Sales"])

#Calculate x-value and regression values
x_holiday = holiday['Temperature']
y_holiday = slope_h*x_holiday + intercept_h
x_values = not_holiday['Temperature']
y_values = slope*x_values + intercept

#Create linear regression equation
eq_holiday = 'y = ' + str(round(slope_h,2)) + "x + " + str(round(intercept_h,2))
eq_regular = 'y = ' + str(round(slope,2)) + "x + " + str(round(intercept,2))

print("Temperature Holiday:",eq_holiday,"R-value:", rvalue_h)
print("Temperature No Holiday:", eq_regular, "R-value:", rvalue)

## After subsetting data, linear regression are both not a good model to fit the two variables
## Positive correlation between temperature and weekly sales during holiday and not during holiday
# Out:
# Temperature Holiday: y = 9131.11x + 824143.69 R-value: 0.13059073194189183
# Temperature No Holiday: y = 8033.54x + 762985.85 R-value: 0.13073203583185242

# %%
# (2) ************************************** FUEL PRICES **************************************
# (2A) What effect does regional fuel prices have on weekly sales?
# Hypothesis: Would expect higher fuel prices would cause a decrease in weekly sales, since less money to spend

#Linear Regression
(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(walmart_holiday['Fuel_Price'], walmart_holiday["Weekly_Sales"])

x_values = walmart_holiday['Fuel_Price']
y_values = slope*x_values + intercept

line_eq = 'y = ' + str(round(slope,2)) + "x + " + str(round(intercept,2))

print(line_eq, round(rvalue,2))

## (1) Negative relationship which suggests that an increase in fuel prices results in a decrease in weekly sales
## (2) R-value is close to 0 suggesting linear regression is not a good fit for data
# Out:
# y = -130443.65x + 1328116.73 -0.09

# %%
# (2B) FUEL PRICES HOLIDAY
# (2B) What effect does regional fuel prices have on holiday weekly sales?
# Hypothesis: Would expect higher fuel prices would cause a decrease in weekly sales, since less money to spend

# Group by Holiday Name and take average of fuel price and weekly sales
fuel_avg = pd.DataFrame(walmart_holiday.groupby('Holiday Name')[['Fuel_Price','Weekly_Sales']].mean())

# Format Weekly Sales
fuel_avg['Fuel_Price'] = fuel_avg['Fuel_Price'].map("${:,.2f}".format)
fuel_avg['Weekly_Sales'] = fuel_avg['Weekly_Sales'].map("${:,.2f}".format)

# Export file
outputfile = "Project 1/Fuel Price/fuel_avg.csv"
fuel_avg.to_csv(outputfile, header = True)

# Add title
fuel_avg = fuel_avg.style.set_caption("Average Fuel Price vs. Weekly Sales During Holidays").set_table_styles([{
    'selector': 'caption',
   'props': [('color', 'black'), ('font-size', '13px'), ('font-weight', 'bold')]
}])

fuel_avg
# Out:
# <style  type="text/css" >
#     #T_1a78174a_2144_11eb_b711_181deafdb758 caption {
#           color: black;
#           font-size: 13px;
#           font-weight: bold;
#     }</style><table id="T_1a78174a_2144_11eb_b711_181deafdb758" ><caption>Average Fuel Price vs. Weekly Sales During Holidays</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Fuel_Price</th>        <th class="col_heading level0 col1" >Weekly_Sales</th>    </tr>    <tr>        <th class="index_name level0" >Holiday Name</th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_1a78174a_2144_11eb_b711_181deafdb758level0_row0" class="row_heading level0 row0" >Christmas</th>
#                         <td id="T_1a78174a_2144_11eb_b711_181deafdb758row0_col0" class="data row0 col0" >$3.17</td>
#                         <td id="T_1a78174a_2144_11eb_b711_181deafdb758row0_col1" class="data row0 col1" >$930,035.53</td>
#             </tr>
#             <tr>
#                         <th id="T_1a78174a_2144_11eb_b711_181deafdb758level0_row1" class="row_heading level0 row1" >Independence Day</th>
#                         <td id="T_1a78174a_2144_11eb_b711_181deafdb758row1_col0" class="data row1 col0" >$3.29</td>
#                         <td id="T_1a78174a_2144_11eb_b711_181deafdb758row1_col1" class="data row1 col1" >$1,088,976.41</td>
#             </tr>
#             <tr>
#                         <th id="T_1a78174a_2144_11eb_b711_181deafdb758level0_row2" class="row_heading level0 row2" >New Year</th>
#                         <td id="T_1a78174a_2144_11eb_b711_181deafdb758row2_col0" class="data row2 col0" >$3.24</td>
#                         <td id="T_1a78174a_2144_11eb_b711_181deafdb758row2_col1" class="data row2 col1" >$649,860.81</td>
#             </tr>
#             <tr>
#                         <th id="T_1a78174a_2144_11eb_b711_181deafdb758level0_row3" class="row_heading level0 row3" >No Holiday</th>
#                         <td id="T_1a78174a_2144_11eb_b711_181deafdb758row3_col0" class="data row3 col0" >$3.40</td>
#                         <td id="T_1a78174a_2144_11eb_b711_181deafdb758row3_col1" class="data row3 col1" >$883,569.08</td>
#             </tr>
#             <tr>
#                         <th id="T_1a78174a_2144_11eb_b711_181deafdb758level0_row4" class="row_heading level0 row4" >Thanksgiving</th>
#                         <td id="T_1a78174a_2144_11eb_b711_181deafdb758row4_col0" class="data row4 col0" >$3.29</td>
#                         <td id="T_1a78174a_2144_11eb_b711_181deafdb758row4_col1" class="data row4 col1" >$980,848.95</td>
#             </tr>
#     </tbody></table>

# %%
# (2B) FUEL PRICES HOLIDAY CONT.

# Group by Is Holiday and take average of fuel price and weekly sales
fuel_is = pd.DataFrame(walmart_holiday.groupby('Is Holiday')[['Fuel_Price','Weekly_Sales']].mean())

# Format Weekly Sales
fuel_is['Fuel_Price'] = fuel_is['Fuel_Price'].map("${:,.2f}".format)
fuel_is['Weekly_Sales'] = fuel_is['Weekly_Sales'].map("${:,.2f}".format)

# Export file
outputfile = "Project 1/Fuel Price/fuel_avg_is.csv"
fuel_is.to_csv(outputfile, header = True)

# Add title
fuel_is = fuel_is.style.set_caption("Average Fuel Price vs. Regular/Holiday Weekly Sales").set_table_styles([{
    'selector': 'caption',
   'props': [('color', 'black'), ('font-size', '13px'), ('font-weight', 'bold')]
}])

fuel_is
# Out:
# <style  type="text/css" >
#     #T_1a85e575_2144_11eb_9e36_181deafdb758 caption {
#           color: black;
#           font-size: 13px;
#           font-weight: bold;
#     }</style><table id="T_1a85e575_2144_11eb_9e36_181deafdb758" ><caption>Average Fuel Price vs. Regular/Holiday Weekly Sales</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Fuel_Price</th>        <th class="col_heading level0 col1" >Weekly_Sales</th>    </tr>    <tr>        <th class="index_name level0" >Is Holiday</th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_1a85e575_2144_11eb_9e36_181deafdb758level0_row0" class="row_heading level0 row0" >Holiday</th>
#                         <td id="T_1a85e575_2144_11eb_9e36_181deafdb758row0_col0" class="data row0 col0" >$3.24</td>
#                         <td id="T_1a85e575_2144_11eb_9e36_181deafdb758row0_col1" class="data row0 col1" >$913,784.66</td>
#             </tr>
#             <tr>
#                         <th id="T_1a85e575_2144_11eb_9e36_181deafdb758level0_row1" class="row_heading level0 row1" >No Holiday</th>
#                         <td id="T_1a85e575_2144_11eb_9e36_181deafdb758row1_col0" class="data row1 col0" >$3.40</td>
#                         <td id="T_1a85e575_2144_11eb_9e36_181deafdb758row1_col1" class="data row1 col1" >$883,569.08</td>
#             </tr>
#     </tbody></table>

# %%
# (2B) FUEL PRICES CONT.

# Calculate linear regression coefficients
(slope_h, intercept_h, rvalue_h, pvalue_h, stderr_h) = stats.linregress(holiday['Fuel_Price'], holiday["Weekly_Sales"])
(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(not_holiday['Fuel_Price'], not_holiday["Weekly_Sales"])

# Calculate x-value and regression values
x_holiday = holiday['Fuel_Price']
y_holiday = slope_h*x_holiday + intercept_h
x_values = not_holiday['Fuel_Price']
y_values = slope*x_values + intercept

# Create linear regression equation
eq_holiday = 'y = ' + str(round(slope_h,2)) + "x + " + str(round(intercept_h,2))
eq_regular = 'y = ' + str(round(slope,2)) + "x + " + str(round(intercept,2))

print("Fuel Price Holiday: ",eq_holiday,"R-value:", round(rvalue_h,2))
print("Fuel Price No Holiday:",eq_regular,"R-value:", round(rvalue,2))

## Negative correlation between fuel price and weekly sales, not surprisingly as fuel prices increases, weekly sales decreases
## since families would have to spend more
# Out:
# Fuel Price Holiday:  y = -435215.53x + 2325356.01 R-value: -0.17
# Fuel Price No Holiday: y = -117757.17x + 1284223.6 R-value: -0.08

# %%
# (3) ************************************** UNEMPLOYMENT RATE **************************************
# (3A) What effect does the regional unemployment rate have on weekly sales?
# Hypothesis: Would expect lower weekly sales with a higher unemployemnt rate in the area

# Categorize unemployment
bins = [min(walmart_holiday['Unemployment']) - 2, 6, 9, max(walmart_holiday['Unemployment']) + 2]
labels = ["Low: <6%", "Normal: 6%-9%" , "High: >9%"]

# Add bin/label to dataframe
walmart_holiday['Unemployment Category'] = pd.cut(walmart_holiday['Unemployment'], bins, labels = labels)

# Display preview of dataframe
walmart_holiday.head()
# Out:
#          Date  Store Holiday Name  Is Holiday  Weekly_Sales  Temperature  \
# 0  2010-02-05      1   No Holiday  No Holiday    1643690.90            6
# 1  2010-02-05      2   No Holiday  No Holiday    2136989.46            5
# 2  2010-02-05      3   No Holiday  No Holiday     461622.22            8
# 3  2010-02-05      4   No Holiday  No Holiday    2135143.87            7
# 4  2010-02-05      5   No Holiday  No Holiday     317173.10            4
#
#       CPI  Unemployment  Fuel_Price Temp Category Unemployment Category
# 0  211.10         8.106        2.57    0°C to 9°C         Normal: 6%-9%
# 1  210.75         8.324        2.57    0°C to 9°C         Normal: 6%-9%
# 2  214.42         7.368        2.57    0°C to 9°C         Normal: 6%-9%
# 3  126.44         8.623        2.60    0°C to 9°C         Normal: 6%-9%
# 4  211.65         6.566        2.57    0°C to 9°C         Normal: 6%-9%

# %%
# (3A) UNEMPLOYMENT CONT.

# Check Average Weekly Sale for Unemployment Category
rate = pd.DataFrame(walmart_holiday.groupby('Unemployment Category')['Weekly_Sales'].mean())

# Format Weekly Sales
rate['Weekly_Sales'] = rate['Weekly_Sales'].map("${:,.2f}".format)

# Export file
outputfile = "Project 1/Unemployment/rate_avg.csv"
rate.to_csv(outputfile, header = True)

# Add title
rate = rate.style.set_caption("Unemployment vs. Average Weekly Sales").set_table_styles([{
    'selector': 'caption',
    'props': [('color', 'black'), ('font-size', '13px'), ('font-weight', 'bold')]
}])

# Display dataframe
rate

## Not surprisingly, from table it suggest when unemployment rate is lower the average weekly sales is higher
## and vice versa, when unemployment rate is high, average weekly sales is lower
# Out:
# <style  type="text/css" >
#     #T_1acaf9d5_2144_11eb_aa2f_181deafdb758 caption {
#           color: black;
#           font-size: 13px;
#           font-weight: bold;
#     }</style><table id="T_1acaf9d5_2144_11eb_aa2f_181deafdb758" ><caption>Unemployment vs. Average Weekly Sales</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Weekly_Sales</th>    </tr>    <tr>        <th class="index_name level0" >Unemployment Category</th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_1acaf9d5_2144_11eb_aa2f_181deafdb758level0_row0" class="row_heading level0 row0" >Low: <6%</th>
#                         <td id="T_1acaf9d5_2144_11eb_aa2f_181deafdb758row0_col0" class="data row0 col0" >$787,068.73</td>
#             </tr>
#             <tr>
#                         <th id="T_1acaf9d5_2144_11eb_aa2f_181deafdb758level0_row1" class="row_heading level0 row1" >Normal: 6%-9%</th>
#                         <td id="T_1acaf9d5_2144_11eb_aa2f_181deafdb758row1_col0" class="data row1 col0" >$923,509.20</td>
#             </tr>
#             <tr>
#                         <th id="T_1acaf9d5_2144_11eb_aa2f_181deafdb758level0_row2" class="row_heading level0 row2" >High: >9%</th>
#                         <td id="T_1acaf9d5_2144_11eb_aa2f_181deafdb758row2_col0" class="data row2 col0" >$793,263.48</td>
#             </tr>
#     </tbody></table>

# %%
# Check Total Weekly Sale for Unemployment Category
rate_ttl = pd.DataFrame(walmart_holiday.groupby('Unemployment Category')['Weekly_Sales'].sum())

# Calculate Percent
rate_ttl['Percentage %'] = rate_ttl['Weekly_Sales']/rate_ttl['Weekly_Sales'].sum()

#Calculate Count 
rate_ttl['Count'] = walmart_holiday.groupby('Unemployment Category')['Weekly_Sales'].count()

# Calculate Percent
rate_ttl['Count Percentage %'] = rate_ttl['Count']/rate_ttl['Count'].sum()

# Format Weekly Sales
rate_ttl['Weekly_Sales'] = rate_ttl['Weekly_Sales'].map("${:,.2f}".format)
rate_ttl['Percentage %'] = rate_ttl['Percentage %'].map("{:.0%}".format)
rate_ttl['Count Percentage %'] = rate_ttl['Count Percentage %'].map("{:.0%}".format)

# Export file
outputfile = "Project 1/Unemployment/rate_ttl.csv"
rate_ttl.to_csv(outputfile, header = True)

# Add title
rate_ttl = rate_ttl.style.set_caption("Unemployment vs. Total Weekly Sales").set_table_styles([{
    'selector': 'caption',
    'props': [('color', 'black'), ('font-size', '13px'), ('font-weight', 'bold')]
}])

# Display dataframe
rate_ttl

## Most of the sales occur when unemployment rate is normal
# Out:
# <style  type="text/css" >
#     #T_1adc62ed_2144_11eb_9917_181deafdb758 caption {
#           color: black;
#           font-size: 13px;
#           font-weight: bold;
#     }</style><table id="T_1adc62ed_2144_11eb_9917_181deafdb758" ><caption>Unemployment vs. Total Weekly Sales</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Weekly_Sales</th>        <th class="col_heading level0 col1" >Percentage %</th>        <th class="col_heading level0 col2" >Count</th>        <th class="col_heading level0 col3" >Count Percentage %</th>    </tr>    <tr>        <th class="index_name level0" >Unemployment Category</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_1adc62ed_2144_11eb_9917_181deafdb758level0_row0" class="row_heading level0 row0" >Low: <6%</th>
#                         <td id="T_1adc62ed_2144_11eb_9917_181deafdb758row0_col0" class="data row0 col0" >$734,335,122.95</td>
#                         <td id="T_1adc62ed_2144_11eb_9917_181deafdb758row0_col1" class="data row0 col1" >11%</td>
#                         <td id="T_1adc62ed_2144_11eb_9917_181deafdb758row0_col2" class="data row0 col2" >933</td>
#                         <td id="T_1adc62ed_2144_11eb_9917_181deafdb758row0_col3" class="data row0 col3" >12%</td>
#             </tr>
#             <tr>
#                         <th id="T_1adc62ed_2144_11eb_9917_181deafdb758level0_row1" class="row_heading level0 row1" >Normal: 6%-9%</th>
#                         <td id="T_1adc62ed_2144_11eb_9917_181deafdb758row1_col0" class="data row1 col0" >$5,035,895,676.42</td>
#                         <td id="T_1adc62ed_2144_11eb_9917_181deafdb758row1_col1" class="data row1 col1" >75%</td>
#                         <td id="T_1adc62ed_2144_11eb_9917_181deafdb758row1_col2" class="data row1 col2" >5453</td>
#                         <td id="T_1adc62ed_2144_11eb_9917_181deafdb758row1_col3" class="data row1 col3" >72%</td>
#             </tr>
#             <tr>
#                         <th id="T_1adc62ed_2144_11eb_9917_181deafdb758level0_row2" class="row_heading level0 row2" >High: >9%</th>
#                         <td id="T_1adc62ed_2144_11eb_9917_181deafdb758row2_col0" class="data row2 col0" >$966,988,187.74</td>
#                         <td id="T_1adc62ed_2144_11eb_9917_181deafdb758row2_col1" class="data row2 col1" >14%</td>
#                         <td id="T_1adc62ed_2144_11eb_9917_181deafdb758row2_col2" class="data row2 col2" >1219</td>
#                         <td id="T_1adc62ed_2144_11eb_9917_181deafdb758row2_col3" class="data row2 col3" >16%</td>
#             </tr>
#     </tbody></table>

# %%
# (3A) UNEMPLOYMENT CONT.

unemployment = walmart_holiday

# Linear Regression
(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(unemployment['Unemployment'], unemployment["Weekly_Sales"])

x_values = unemployment['Unemployment']
y_values = slope*x_values + intercept

line_eq = 'y = ' + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(line_eq, rvalue)

## Positive correlation between unemployment rate and weekly sales, not surprising, higher unemployment rate
## results in higher weekly sales.
## R-value is not high so linear regression is not a good model fit for this data
# Out:
# y = 16337.38x + 758023.6 0.047768966800300273

# %%
# (3B) UNEMPLOYMENT HOLIDAY
# (3B) What effect does the regional unemployment rate have on holiday weekly sales?
# Hypothesis: Would expect lower weekly sales with a higher unemployemnt rate in the area even during holidays

# Check Average Weekly Sale for Unemployment Category
rate_is = pd.DataFrame(walmart_holiday.groupby(['Is Holiday','Unemployment Category'])['Weekly_Sales'].mean())

# Format Weekly Sales
rate_is['Weekly_Sales'] = rate_is['Weekly_Sales'].map("${:,.2f}".format)

# Export file
outputfile = "Project 1/Unemployment/rate_avg_is.csv"
rate_is.to_csv(outputfile, header = True)

# Add title
rate_is = rate_is.style.set_caption("Unemployment vs. Average Regular/Holiday Weekly Sales").set_table_styles([{
    'selector': 'caption',
    'props': [('color', 'black'), ('font-size', '13px'), ('font-weight', 'bold')]
}])

# Display dataframe
rate_is

## Intereseting results, when unemployemnts rate is high or normal, weekly sales is higher during the holidays
## and lower when unmployement rate is low.
## When it is not the holiday it has normal results where low unemployment rate has higher spending and vice versa
# Out:
# <style  type="text/css" >
#     #T_1af71a3d_2144_11eb_91a8_181deafdb758 caption {
#           color: black;
#           font-size: 13px;
#           font-weight: bold;
#     }</style><table id="T_1af71a3d_2144_11eb_91a8_181deafdb758" ><caption>Unemployment vs. Average Regular/Holiday Weekly Sales</caption><thead>    <tr>        <th class="blank" ></th>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Weekly_Sales</th>    </tr>    <tr>        <th class="index_name level0" >Is Holiday</th>        <th class="index_name level1" >Unemployment Category</th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_1af71a3d_2144_11eb_91a8_181deafdb758level0_row0" class="row_heading level0 row0" rowspan=3>Holiday</th>
#                         <th id="T_1af71a3d_2144_11eb_91a8_181deafdb758level1_row0" class="row_heading level1 row0" >Low: <6%</th>
#                         <td id="T_1af71a3d_2144_11eb_91a8_181deafdb758row0_col0" class="data row0 col0" >$678,963.14</td>
#             </tr>
#             <tr>
#                                 <th id="T_1af71a3d_2144_11eb_91a8_181deafdb758level1_row1" class="row_heading level1 row1" >Normal: 6%-9%</th>
#                         <td id="T_1af71a3d_2144_11eb_91a8_181deafdb758row1_col0" class="data row1 col0" >$961,825.94</td>
#             </tr>
#             <tr>
#                                 <th id="T_1af71a3d_2144_11eb_91a8_181deafdb758level1_row2" class="row_heading level1 row2" >High: >9%</th>
#                         <td id="T_1af71a3d_2144_11eb_91a8_181deafdb758row2_col0" class="data row2 col0" >$874,418.03</td>
#             </tr>
#             <tr>
#                         <th id="T_1af71a3d_2144_11eb_91a8_181deafdb758level0_row3" class="row_heading level0 row3" rowspan=3>No Holiday</th>
#                         <th id="T_1af71a3d_2144_11eb_91a8_181deafdb758level1_row3" class="row_heading level1 row3" >Low: <6%</th>
#                         <td id="T_1af71a3d_2144_11eb_91a8_181deafdb758row3_col0" class="data row3 col0" >$795,837.43</td>
#             </tr>
#             <tr>
#                                 <th id="T_1af71a3d_2144_11eb_91a8_181deafdb758level1_row4" class="row_heading level1 row4" >Normal: 6%-9%</th>
#                         <td id="T_1af71a3d_2144_11eb_91a8_181deafdb758row4_col0" class="data row4 col0" >$920,311.70</td>
#             </tr>
#             <tr>
#                                 <th id="T_1af71a3d_2144_11eb_91a8_181deafdb758level1_row5" class="row_heading level1 row5" >High: >9%</th>
#                         <td id="T_1af71a3d_2144_11eb_91a8_181deafdb758row5_col0" class="data row5 col0" >$786,404.34</td>
#             </tr>
#     </tbody></table>

# %%
# (3B) UNEMPLOYMENT HOLIDAY CONT.

# Check Average Weekly Sale for Unemployment Category
rate_holiday = pd.DataFrame(walmart_holiday.groupby(['Holiday Name','Unemployment Category'])['Weekly_Sales'].mean())

# Format Weekly Sales
rate_holiday['Weekly_Sales'] = rate_holiday['Weekly_Sales'].map("${:,.2f}".format)

# Export file
outputfile = "Project 1/Unemployment/rate_avg_holiday.csv"
rate_holiday.to_csv(outputfile, header = True)

# Add title
rate_holiday = rate_holiday.style.set_caption("Unemployment vs. Average Weekly Sales During Holiday").set_table_styles([{
    'selector': 'caption',
    'props': [('color', 'black'), ('font-size', '13px'), ('font-weight', 'bold')]
}])

# Display dataframe
rate_holiday

## Surprisingly during Christmas average weekly_sales is even more when unemployemnt is very high or normal 
## compared to when it's low
# Out:
# <style  type="text/css" >
#     #T_1b039c3b_2144_11eb_ab0b_181deafdb758 caption {
#           color: black;
#           font-size: 13px;
#           font-weight: bold;
#     }</style><table id="T_1b039c3b_2144_11eb_ab0b_181deafdb758" ><caption>Unemployment vs. Average Weekly Sales During Holiday</caption><thead>    <tr>        <th class="blank" ></th>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Weekly_Sales</th>    </tr>    <tr>        <th class="index_name level0" >Holiday Name</th>        <th class="index_name level1" >Unemployment Category</th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_1b039c3b_2144_11eb_ab0b_181deafdb758level0_row0" class="row_heading level0 row0" rowspan=3>Christmas</th>
#                         <th id="T_1b039c3b_2144_11eb_ab0b_181deafdb758level1_row0" class="row_heading level1 row0" >Low: <6%</th>
#                         <td id="T_1b039c3b_2144_11eb_ab0b_181deafdb758row0_col0" class="data row0 col0" >$582,980.24</td>
#             </tr>
#             <tr>
#                                 <th id="T_1b039c3b_2144_11eb_ab0b_181deafdb758level1_row1" class="row_heading level1 row1" >Normal: 6%-9%</th>
#                         <td id="T_1b039c3b_2144_11eb_ab0b_181deafdb758row1_col0" class="data row1 col0" >$983,600.09</td>
#             </tr>
#             <tr>
#                                 <th id="T_1b039c3b_2144_11eb_ab0b_181deafdb758level1_row2" class="row_heading level1 row2" >High: >9%</th>
#                         <td id="T_1b039c3b_2144_11eb_ab0b_181deafdb758row2_col0" class="data row2 col0" >$912,115.87</td>
#             </tr>
#             <tr>
#                         <th id="T_1b039c3b_2144_11eb_ab0b_181deafdb758level0_row3" class="row_heading level0 row3" rowspan=3>Independence Day</th>
#                         <th id="T_1b039c3b_2144_11eb_ab0b_181deafdb758level1_row3" class="row_heading level1 row3" >Low: <6%</th>
#                         <td id="T_1b039c3b_2144_11eb_ab0b_181deafdb758row3_col0" class="data row3 col0" >$1,286,983.19</td>
#             </tr>
#             <tr>
#                                 <th id="T_1b039c3b_2144_11eb_ab0b_181deafdb758level1_row4" class="row_heading level1 row4" >Normal: 6%-9%</th>
#                         <td id="T_1b039c3b_2144_11eb_ab0b_181deafdb758row4_col0" class="data row4 col0" >$1,117,226.10</td>
#             </tr>
#             <tr>
#                                 <th id="T_1b039c3b_2144_11eb_ab0b_181deafdb758level1_row5" class="row_heading level1 row5" >High: >9%</th>
#                         <td id="T_1b039c3b_2144_11eb_ab0b_181deafdb758row5_col0" class="data row5 col0" >$852,223.39</td>
#             </tr>
#             <tr>
#                         <th id="T_1b039c3b_2144_11eb_ab0b_181deafdb758level0_row6" class="row_heading level0 row6" rowspan=3>New Year</th>
#                         <th id="T_1b039c3b_2144_11eb_ab0b_181deafdb758level1_row6" class="row_heading level1 row6" >Low: <6%</th>
#                         <td id="T_1b039c3b_2144_11eb_ab0b_181deafdb758row6_col0" class="data row6 col0" >$390,401.22</td>
#             </tr>
#             <tr>
#                                 <th id="T_1b039c3b_2144_11eb_ab0b_181deafdb758level1_row7" class="row_heading level1 row7" >Normal: 6%-9%</th>
#                         <td id="T_1b039c3b_2144_11eb_ab0b_181deafdb758row7_col0" class="data row7 col0" >$701,170.50</td>
#             </tr>
#             <tr>
#                                 <th id="T_1b039c3b_2144_11eb_ab0b_181deafdb758level1_row8" class="row_heading level1 row8" >High: >9%</th>
#                         <td id="T_1b039c3b_2144_11eb_ab0b_181deafdb758row8_col0" class="data row8 col0" >$674,460.27</td>
#             </tr>
#             <tr>
#                         <th id="T_1b039c3b_2144_11eb_ab0b_181deafdb758level0_row9" class="row_heading level0 row9" rowspan=3>No Holiday</th>
#                         <th id="T_1b039c3b_2144_11eb_ab0b_181deafdb758level1_row9" class="row_heading level1 row9" >Low: <6%</th>
#                         <td id="T_1b039c3b_2144_11eb_ab0b_181deafdb758row9_col0" class="data row9 col0" >$795,837.43</td>
#             </tr>
#             <tr>
#                                 <th id="T_1b039c3b_2144_11eb_ab0b_181deafdb758level1_row10" class="row_heading level1 row10" >Normal: 6%-9%</th>
#                         <td id="T_1b039c3b_2144_11eb_ab0b_181deafdb758row10_col0" class="data row10 col0" >$920,311.70</td>
#             </tr>
#             <tr>
#                                 <th id="T_1b039c3b_2144_11eb_ab0b_181deafdb758level1_row11" class="row_heading level1 row11" >High: >9%</th>
#                         <td id="T_1b039c3b_2144_11eb_ab0b_181deafdb758row11_col0" class="data row11 col0" >$786,404.34</td>
#             </tr>
#             <tr>
#                         <th id="T_1b039c3b_2144_11eb_ab0b_181deafdb758level0_row12" class="row_heading level0 row12" rowspan=3>Thanksgiving</th>
#                         <th id="T_1b039c3b_2144_11eb_ab0b_181deafdb758level1_row12" class="row_heading level1 row12" >Low: <6%</th>
#                         <td id="T_1b039c3b_2144_11eb_ab0b_181deafdb758row12_col0" class="data row12 col0" >$595,662.61</td>
#             </tr>
#             <tr>
#                                 <th id="T_1b039c3b_2144_11eb_ab0b_181deafdb758level1_row13" class="row_heading level1 row13" >Normal: 6%-9%</th>
#                         <td id="T_1b039c3b_2144_11eb_ab0b_181deafdb758row13_col0" class="data row13 col0" >$1,045,324.73</td>
#             </tr>
#             <tr>
#                                 <th id="T_1b039c3b_2144_11eb_ab0b_181deafdb758level1_row14" class="row_heading level1 row14" >High: >9%</th>
#                         <td id="T_1b039c3b_2144_11eb_ab0b_181deafdb758row14_col0" class="data row14 col0" >$976,704.89</td>
#             </tr>
#     </tbody></table>

# %%
# (3B) UNEMPLOYMENT HOLIDAY CONT.

# Calculate linear regression coefficients
(slope_h, intercept_h, rvalue_h, pvalue_h, stderr_h) = stats.linregress(holiday['Unemployment'], holiday["Weekly_Sales"])
(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(not_holiday['Unemployment'], not_holiday["Weekly_Sales"])

# Calculate x-value and regression values
x_holiday = holiday['Unemployment']
y_holiday = slope_h*x_holiday + intercept_h
x_values = not_holiday['Unemployment']
y_values = slope*x_values + intercept

# Create linear regression equation
eq_holiday = 'y = ' + str(round(slope_h,2)) + "x + " + str(round(intercept_h,2))
eq_regular = 'y = ' + str(round(slope,2)) + "x + " + str(round(intercept,2))

print("Unemployment Holiday: ",eq_holiday,"R-value:", round(rvalue_h,2))
print("Unemployment No Holiday:",eq_regular,"R-value:", round(rvalue,2))

## Surprising correlation, as unemployment rate get higher weekly sales get higher
## R-value is low, linear regression is not a good fit for data
# Out:
# Unemployment Holiday:  y = 43747.44x + 572618.21 R-value: 0.1
# Unemployment No Holiday: y = 14058.93x + 773499.26 R-value: 0.04

# %%
# (4) ************************************** CPI RATE **************************************
# (4A) What effect does CPI have on weekly sales?
# Hypothesis: Would expect lower weekly sales with a higher CPI as it'll cost more to maintain the same standard of living

cpi = walmart_holiday 

# Linear Regression
(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(cpi['CPI'], cpi["Weekly_Sales"])

# Calculate x_value and regression values
x_values = cpi['CPI']
y_values = slope*x_values + intercept

# Create equation
line_eq = 'y = ' + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(line_eq, rvalue)

## Negative correlation between CPI and weekly sales, not surprising, higher CPI results in 
## a lower weekly sales, since with a higher CPI as it'll cost more to maintain the same standard of living.
## R-value is not high so linear regression is a good model fit for this data
# Out:
# y = -1359.58x + 1120367.03 -0.08414951460453712

# %%
# (4B) CPI HOLIDAY
# (4B) What effect does CPI have on weekly sales during holidays?
# Hypothesis: Would expect lower weekly sales with a higher CPI as it'll cost more to maintain the same standard of living

# Groupby Is Holiday and create dataframe
cpi_is = pd.DataFrame(walmart_holiday.groupby('Is Holiday')[['CPI','Weekly_Sales']].mean())

# Format weekly sales
cpi_is['Weekly_Sales'] = cpi_is['Weekly_Sales'].map("${:,.2f}".format)

# Export file
outputfile = "Project 1/CPI/cpi_is_avg.csv"
cpi_is.to_csv(outputfile, header = True)

# Add title
cpi_is = cpi_is.style.set_caption("CPI vs. Average Regular/Holiday Weekly Sales").set_table_styles([{
    'selector': 'caption',
    'props': [('color', 'black'), ('font-size', '13px'), ('font-weight', 'bold')]
}])

# Display dataframe
cpi_is
# Out:
# <style  type="text/css" >
#     #T_1b2ba242_2144_11eb_955c_181deafdb758 caption {
#           color: black;
#           font-size: 13px;
#           font-weight: bold;
#     }</style><table id="T_1b2ba242_2144_11eb_955c_181deafdb758" ><caption>CPI vs. Average Regular/Holiday Weekly Sales</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >CPI</th>        <th class="col_heading level0 col1" >Weekly_Sales</th>    </tr>    <tr>        <th class="index_name level0" >Is Holiday</th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_1b2ba242_2144_11eb_955c_181deafdb758level0_row0" class="row_heading level0 row0" >Holiday</th>
#                         <td id="T_1b2ba242_2144_11eb_955c_181deafdb758row0_col0" class="data row0 col0" >172.426701</td>
#                         <td id="T_1b2ba242_2144_11eb_955c_181deafdb758row0_col1" class="data row0 col1" >$913,784.66</td>
#             </tr>
#             <tr>
#                         <th id="T_1b2ba242_2144_11eb_955c_181deafdb758level0_row1" class="row_heading level0 row1" >No Holiday</th>
#                         <td id="T_1b2ba242_2144_11eb_955c_181deafdb758row1_col0" class="data row1 col0" >172.463764</td>
#                         <td id="T_1b2ba242_2144_11eb_955c_181deafdb758row1_col1" class="data row1 col1" >$883,569.08</td>
#             </tr>
#     </tbody></table>

# %%
# (4B) CPI HOLIDAY CONT.

# Groupby Is Holiday and create dataframe
cpi_holiday = pd.DataFrame(walmart_holiday.groupby('Holiday Name')[['CPI', 'Weekly_Sales']].mean())

# Format weekly sales
cpi_holiday['Weekly_Sales'] = cpi_holiday['Weekly_Sales'].map("${:,.2f}".format)

# Export file
outputfile = "Project 1/CPI/cpi_holiday_avg.csv"
cpi_holiday.to_csv(outputfile, header = True)

# Add title
cpi_holiday = cpi_holiday.style.set_caption("CPI vs. Average Weekly Sales During Holidays").set_table_styles([{
    'selector': 'caption',
    'props': [('color', 'black'), ('font-size', '13px'), ('font-weight', 'bold')]
}])

# Display dataframe
cpi_holiday
# Out:
# <style  type="text/css" >
#     #T_1b388057_2144_11eb_b39b_181deafdb758 caption {
#           color: black;
#           font-size: 13px;
#           font-weight: bold;
#     }</style><table id="T_1b388057_2144_11eb_b39b_181deafdb758" ><caption>CPI vs. Average Weekly Sales During Holidays</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >CPI</th>        <th class="col_heading level0 col1" >Weekly_Sales</th>    </tr>    <tr>        <th class="index_name level0" >Holiday Name</th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_1b388057_2144_11eb_b39b_181deafdb758level0_row0" class="row_heading level0 row0" >Christmas</th>
#                         <td id="T_1b388057_2144_11eb_b39b_181deafdb758row0_col0" class="data row0 col0" >171.999611</td>
#                         <td id="T_1b388057_2144_11eb_b39b_181deafdb758row0_col1" class="data row0 col1" >$930,035.53</td>
#             </tr>
#             <tr>
#                         <th id="T_1b388057_2144_11eb_b39b_181deafdb758level0_row1" class="row_heading level0 row1" >Independence Day</th>
#                         <td id="T_1b388057_2144_11eb_b39b_181deafdb758row1_col0" class="data row1 col0" >171.697111</td>
#                         <td id="T_1b388057_2144_11eb_b39b_181deafdb758row1_col1" class="data row1 col1" >$1,088,976.41</td>
#             </tr>
#             <tr>
#                         <th id="T_1b388057_2144_11eb_b39b_181deafdb758level0_row2" class="row_heading level0 row2" >New Year</th>
#                         <td id="T_1b388057_2144_11eb_b39b_181deafdb758row2_col0" class="data row2 col0" >173.272222</td>
#                         <td id="T_1b388057_2144_11eb_b39b_181deafdb758row2_col1" class="data row2 col1" >$649,860.81</td>
#             </tr>
#             <tr>
#                         <th id="T_1b388057_2144_11eb_b39b_181deafdb758level0_row3" class="row_heading level0 row3" >No Holiday</th>
#                         <td id="T_1b388057_2144_11eb_b39b_181deafdb758row3_col0" class="data row3 col0" >172.463764</td>
#                         <td id="T_1b388057_2144_11eb_b39b_181deafdb758row3_col1" class="data row3 col1" >$883,569.08</td>
#             </tr>
#             <tr>
#                         <th id="T_1b388057_2144_11eb_b39b_181deafdb758level0_row4" class="row_heading level0 row4" >Thanksgiving</th>
#                         <td id="T_1b388057_2144_11eb_b39b_181deafdb758row4_col0" class="data row4 col0" >172.880222</td>
#                         <td id="T_1b388057_2144_11eb_b39b_181deafdb758row4_col1" class="data row4 col1" >$980,848.95</td>
#             </tr>
#     </tbody></table>

# %%
# (4) CPI HOLIDAY CONT.

# Calculate linear regression coefficients
(slope_h, intercept_h, rvalue_h, pvalue_h, stderr_h) = stats.linregress(holiday['CPI'], holiday["Weekly_Sales"])
(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(not_holiday['CPI'], not_holiday["Weekly_Sales"])

# Calculate x-value and regression values
x_holiday = holiday['CPI']
y_holiday = slope_h*x_holiday + intercept_h
x_values = not_holiday['CPI']
y_values = slope*x_values + intercept

# Create linear regression equation
eq_holiday = 'y = ' + str(round(slope_h,2)) + "x + " + str(round(intercept_h,2))
eq_regular = 'y = ' + str(round(slope,2)) + "x + " + str(round(intercept,2))

print("CPI Holiday: ",eq_holiday,"R-value:", round(rvalue_h,2))
print("CPI No Holiday:",eq_regular,"R-value:", round(rvalue,2))

## Not surprising correlation, increase in CPI cause a decrease in spending during holidays
## R-value is low, linear regression is not a good fit for data
# Out:
# CPI Holiday:  y = -1868.69x + 1235997.02 R-value: -0.09
# CPI No Holiday: y = -1317.09x + 1110720.02 R-value: -0.08

# %%
# (5) ************************************** SUMMARY **************************************
# IS HOLIDAY SUMMARY
summary = walmart_holiday

# Aggregrate variables
isholiday_summary = summary.groupby('Is Holiday').agg({'Weekly_Sales': 'mean',
                                   'Temperature':'mean',
                                  'Fuel_Price': 'mean',
                                  'Unemployment': 'mean',
                                  'CPI':'mean'
                                  })

# Format columns
isholiday_summary['Weekly_Sales'] = pd.DataFrame(isholiday_summary['Weekly_Sales'].map("${:,.2f}".format))
isholiday_summary['Temperature'] = pd.DataFrame(isholiday_summary['Temperature'].map("{:,.0f} °C".format))
isholiday_summary['Fuel_Price'] = pd.DataFrame(isholiday_summary['Fuel_Price'].map("${:,.2f}".format))
isholiday_summary['Unemployment'] = pd.DataFrame(isholiday_summary['Unemployment'].map("{:,.2f}%".format))
isholiday_summary['CPI'] = pd.DataFrame(isholiday_summary['CPI'].map("{:,.2f}".format))

# Export file
outputfile = "Project 1/Summary/summary_is.csv"
isholiday_summary.to_csv(outputfile, header = True)

# Add title
isholiday_summary = isholiday_summary.style.set_caption("Is Holiday Summary Average").set_table_styles([{
    'selector': 'caption',
    'props': [('color', 'black'), ('font-size', '13px'), ('font-weight', 'bold')]
}])

# Display dataframe
isholiday_summary
# Out:
# <style  type="text/css" >
#     #T_1b54311b_2144_11eb_a5db_181deafdb758 caption {
#           color: black;
#           font-size: 13px;
#           font-weight: bold;
#     }</style><table id="T_1b54311b_2144_11eb_a5db_181deafdb758" ><caption>Is Holiday Summary Average</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Weekly_Sales</th>        <th class="col_heading level0 col1" >Temperature</th>        <th class="col_heading level0 col2" >Fuel_Price</th>        <th class="col_heading level0 col3" >Unemployment</th>        <th class="col_heading level0 col4" >CPI</th>    </tr>    <tr>        <th class="index_name level0" >Is Holiday</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_1b54311b_2144_11eb_a5db_181deafdb758level0_row0" class="row_heading level0 row0" >Holiday</th>
#                         <td id="T_1b54311b_2144_11eb_a5db_181deafdb758row0_col0" class="data row0 col0" >$913,784.66</td>
#                         <td id="T_1b54311b_2144_11eb_a5db_181deafdb758row0_col1" class="data row0 col1" >10 °C</td>
#                         <td id="T_1b54311b_2144_11eb_a5db_181deafdb758row0_col2" class="data row0 col2" >$3.24</td>
#                         <td id="T_1b54311b_2144_11eb_a5db_181deafdb758row0_col3" class="data row0 col3" >7.80%</td>
#                         <td id="T_1b54311b_2144_11eb_a5db_181deafdb758row0_col4" class="data row0 col4" >172.43</td>
#             </tr>
#             <tr>
#                         <th id="T_1b54311b_2144_11eb_a5db_181deafdb758level0_row1" class="row_heading level0 row1" >No Holiday</th>
#                         <td id="T_1b54311b_2144_11eb_a5db_181deafdb758row1_col0" class="data row1 col0" >$883,569.08</td>
#                         <td id="T_1b54311b_2144_11eb_a5db_181deafdb758row1_col1" class="data row1 col1" >15 °C</td>
#                         <td id="T_1b54311b_2144_11eb_a5db_181deafdb758row1_col2" class="data row1 col2" >$3.40</td>
#                         <td id="T_1b54311b_2144_11eb_a5db_181deafdb758row1_col3" class="data row1 col3" >7.83%</td>
#                         <td id="T_1b54311b_2144_11eb_a5db_181deafdb758row1_col4" class="data row1 col4" >172.46</td>
#             </tr>
#     </tbody></table>

# %%
# (5) SUMMARY CONT.
# HOLIDAY NAME SUMMARY

# Aggregrate variables
holiday_summary = summary.groupby('Holiday Name').agg({'Weekly_Sales': 'mean',
                                   'Temperature':'mean',
                                  'Fuel_Price': 'mean',
                                  'Unemployment': 'mean',
                                  'CPI':'mean'
                                  })

# Format columns
holiday_summary['Weekly_Sales'] = pd.DataFrame(holiday_summary['Weekly_Sales'].map("${:,.2f}".format))
holiday_summary['Temperature'] = pd.DataFrame(holiday_summary['Temperature'].map("{:,.0f} °C".format))
holiday_summary['Fuel_Price'] = pd.DataFrame(holiday_summary['Fuel_Price'].map("${:,.2f}".format))
holiday_summary['Unemployment'] = pd.DataFrame(holiday_summary['Unemployment'].map("{:,.2f}%".format))
holiday_summary['CPI'] = pd.DataFrame(holiday_summary['CPI'].map("{:,.2f}".format))

# Export
# Export file
outputfile = "Project 1/Summary/summary_holiday.csv"
holiday_summary.to_csv(outputfile, header = True)

# Add title
holiday_summary = holiday_summary.style.set_caption("Holiday Summary Average").set_table_styles([{
    'selector': 'caption',
    'props': [('color', 'black'), ('font-size', '13px'), ('font-weight', 'bold')]
}])

# Display dataframe
holiday_summary
# Out:
# <style  type="text/css" >
#     #T_1b6770e2_2144_11eb_98fd_181deafdb758 caption {
#           color: black;
#           font-size: 13px;
#           font-weight: bold;
#     }</style><table id="T_1b6770e2_2144_11eb_98fd_181deafdb758" ><caption>Holiday Summary Average</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Weekly_Sales</th>        <th class="col_heading level0 col1" >Temperature</th>        <th class="col_heading level0 col2" >Fuel_Price</th>        <th class="col_heading level0 col3" >Unemployment</th>        <th class="col_heading level0 col4" >CPI</th>    </tr>    <tr>        <th class="index_name level0" >Holiday Name</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_1b6770e2_2144_11eb_98fd_181deafdb758level0_row0" class="row_heading level0 row0" >Christmas</th>
#                         <td id="T_1b6770e2_2144_11eb_98fd_181deafdb758row0_col0" class="data row0 col0" >$930,035.53</td>
#                         <td id="T_1b6770e2_2144_11eb_98fd_181deafdb758row0_col1" class="data row0 col1" >3 °C</td>
#                         <td id="T_1b6770e2_2144_11eb_98fd_181deafdb758row0_col2" class="data row0 col2" >$3.17</td>
#                         <td id="T_1b6770e2_2144_11eb_98fd_181deafdb758row0_col3" class="data row0 col3" >7.93%</td>
#                         <td id="T_1b6770e2_2144_11eb_98fd_181deafdb758row0_col4" class="data row0 col4" >172.00</td>
#             </tr>
#             <tr>
#                         <th id="T_1b6770e2_2144_11eb_98fd_181deafdb758level0_row1" class="row_heading level0 row1" >Independence Day</th>
#                         <td id="T_1b6770e2_2144_11eb_98fd_181deafdb758row1_col0" class="data row1 col0" >$1,088,976.41</td>
#                         <td id="T_1b6770e2_2144_11eb_98fd_181deafdb758row1_col1" class="data row1 col1" >26 °C</td>
#                         <td id="T_1b6770e2_2144_11eb_98fd_181deafdb758row1_col2" class="data row1 col2" >$3.29</td>
#                         <td id="T_1b6770e2_2144_11eb_98fd_181deafdb758row1_col3" class="data row1 col3" >7.92%</td>
#                         <td id="T_1b6770e2_2144_11eb_98fd_181deafdb758row1_col4" class="data row1 col4" >171.70</td>
#             </tr>
#             <tr>
#                         <th id="T_1b6770e2_2144_11eb_98fd_181deafdb758level0_row2" class="row_heading level0 row2" >New Year</th>
#                         <td id="T_1b6770e2_2144_11eb_98fd_181deafdb758row2_col0" class="data row2 col0" >$649,860.81</td>
#                         <td id="T_1b6770e2_2144_11eb_98fd_181deafdb758row2_col1" class="data row2 col1" >2 °C</td>
#                         <td id="T_1b6770e2_2144_11eb_98fd_181deafdb758row2_col2" class="data row2 col2" >$3.24</td>
#                         <td id="T_1b6770e2_2144_11eb_98fd_181deafdb758row2_col3" class="data row2 col3" >7.56%</td>
#                         <td id="T_1b6770e2_2144_11eb_98fd_181deafdb758row2_col4" class="data row2 col4" >173.27</td>
#             </tr>
#             <tr>
#                         <th id="T_1b6770e2_2144_11eb_98fd_181deafdb758level0_row3" class="row_heading level0 row3" >No Holiday</th>
#                         <td id="T_1b6770e2_2144_11eb_98fd_181deafdb758row3_col0" class="data row3 col0" >$883,569.08</td>
#                         <td id="T_1b6770e2_2144_11eb_98fd_181deafdb758row3_col1" class="data row3 col1" >15 °C</td>
#                         <td id="T_1b6770e2_2144_11eb_98fd_181deafdb758row3_col2" class="data row3 col2" >$3.40</td>
#                         <td id="T_1b6770e2_2144_11eb_98fd_181deafdb758row3_col3" class="data row3 col3" >7.83%</td>
#                         <td id="T_1b6770e2_2144_11eb_98fd_181deafdb758row3_col4" class="data row3 col4" >172.46</td>
#             </tr>
#             <tr>
#                         <th id="T_1b6770e2_2144_11eb_98fd_181deafdb758level0_row4" class="row_heading level0 row4" >Thanksgiving</th>
#                         <td id="T_1b6770e2_2144_11eb_98fd_181deafdb758row4_col0" class="data row4 col0" >$980,848.95</td>
#                         <td id="T_1b6770e2_2144_11eb_98fd_181deafdb758row4_col1" class="data row4 col1" >9 °C</td>
#                         <td id="T_1b6770e2_2144_11eb_98fd_181deafdb758row4_col2" class="data row4 col2" >$3.29</td>
#                         <td id="T_1b6770e2_2144_11eb_98fd_181deafdb758row4_col3" class="data row4 col3" >7.74%</td>
#                         <td id="T_1b6770e2_2144_11eb_98fd_181deafdb758row4_col4" class="data row4 col4" >172.88</td>
#             </tr>
#     </tbody></table>

# %%
walmart_holiday.to_csv("Project 1/final_df.csv", header = True)
