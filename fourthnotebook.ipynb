# %%
import os
os.getcwd()
# Out:
# '/Users/ronaldclarke/Desktop/GitHub/Project-1'

# %%
# %run thirdnotebook.ipynb
# Out:
# {'meta': {'code': 200},
#  'response': {'holidays': [{'country': {'id': 'us', 'name': 'United States'},
#                             'date': {'datetime': {'day': 1,
#                                                   'month': 1,
#                                                   'year': 2010},
#                                      'iso': '2010-01-01'},
#                             'description': "New Year's Day is the first day of "
#                                            'the Gregorian calendar, which is '
#                                            'widely used in many countries such '
#                                            'as the USA.',
#                             'locations': 'All',
#                             'name': "New Year's Day",
#                             'states': 'All',
#                             'type': ['National holiday']},
#                            {'country': {'id': 'us', 'name': 'United States'},
#                             'date': {'datetime': {'day': 6,
#                                                   'month': 1,
#                                                   'year': 2010},
#                                      'iso': '2010-01-06'},
#                             'description': 'Many people in the United States '
#                                            'annually observe Epiphany, or '
#                                            'Three Kings’ Day, on January 6. It '
#                                            'is a Christian observance and a '
#                                            'public holiday in the US Virgin '
#                                            'Islands.',
#                             'locations': 'All',
#                             'name': 'Epiphany',
#                             'states': 'All',
#                             'type': ['Christian']},
#                            {'country': {'id': 'us', 'name': 'United States'},
#                             'date': {'datetime': {'day': 7,
#                                                   'month': 1,
#                                                   'year': 2010},
#                                      'iso': '2010-01-07'},
#                             'description': 'Many Orthodox Christian churches '
#                                            'in countries such as the United '
#                                            'States observe Christmas Day on or '
#                                            'near January 7 in the Gregorian '
#                                            'calendar.',
#                             'locations': 'All',
#                             'name': 'Orthodox Christmas Day',
#                             'states': 'All',
#                             'type': ['Orthodox']},
#                            {'country': {'id': 'us', 'name': 'United States'},
#                             'date': {'datetime': {'day': 7,
#                                                   'month': 1,
#                                                   'year': 2010},
#                                      'iso': '2010-01-07'},
#                             'description': 'Many people celebrate '
#                                            'International Programmers’ Day on '
#                                            'January 7, while others observe '
#                                            'this event on the 256th day of the '
#                                            'year, usually on September 13 or '
#                                            'on September 12 in leap years.',
#                             'locations': 'All',
#                             'name': "International Programmers' Day",
#                             'states': 'All',
#                             'type': ['Worldwide observance']},
#                            {'country': {'id': 'us', 'name': 'United States'},
#                             'date': {'datetime': {'day': 13,
#                                                   'month': 1,
#                                                   'year': 2010},
#                                      'iso': '2010-01-13'},
#                             'description': 'Stephen Foster Memorial Day is '
#                                            'annually observed in the United '
#                                            'States on January 13. The day '
#                                            'remembers the achievements of '
#                                            'Stephen Foster, who is known as '
#                                            'the “father of American music”.',
#                             'locations': 'All',
#                             'name': 'Stephen Foster Memorial Day',
#                             'states': 'All',
#                             'type': ['Observance']},
#                            {'country': {'id': 'us', 'name': 'United States'},
#                             'date': {'datetime': {'day': 14,
#                                                   'month': 1,
#                                                   'year': 2010},
#                                      'iso': '2010-01-14'},
#                             'description': 'Many Orthodox Christian churches '
#                                            'in countries such as the United '
#                                            'States celebrate New Year’s Day on '
#                                            'January 14 in the Gregorian '
#                                            'calendar.',
#                             'locations': 'All',
#                             'name': 'Orthodox New Year',
#                             'states': 'All',
#                             'type': ['Orthodox']},
#                            {'country': {'id': 'us', 'name': 'United States'},
#                             'date': {'datetime': {'day': 15,
#                                                   'month': 1,
#                                                   'year': 2010},
#                                      'iso': '2010-01-15'},
#                             'description': 'Lee-Jackson Day is an annual state '
#                                            'holiday in Virginia, the United '
#                                            'States, on the Friday before '
#                                            'Martin Luther King Day in January.',
#                             'locations': 'VA',
#                             'name': 'Lee-Jackson Day',
#                             'states': [{'abbrev': 'VA',
#                                         'exception': None,
#                                         'id': 52,
#                                         'iso': 'us-va',
#                                         'name': 'Virginia'}],
#                             'type': ['Local holiday']},
#                            {'country': {'id': 'us', 'name': 'United States'},
#                             'date': {'datetime': {'day': 18,
#                                                   'month': 1,
#                                                   'year': 2010},
#                                      'iso': '2010-01-18'},
#                             'description': 'Martin Luther King Day marks the '
#                                            'anniversary of the date of birth '
#                                            'of the influential American civil '
#                                            'right leader of the same name.',
#                             'locations': 'All',
#                             'name': 'Martin Luther King Jr. Day',
#                             'states': 'All',
#                             'type': ['National holiday']},
#                            {'country': {'id': 'us', 'name': 'United States'},
#                             'date': {'datetime': {'day': 18,
#                                                   'month': 1,
#                                                   'year': 2010},
#                                      'iso': '2010-01-18'},
#                             'description': 'Robert E. Lee’s birthday is an '
#                                            'annual official state holiday that '
#                                            'is shared with Martin Luther '
#                                            'King’s birthday in some parts of '
#                                            'the US.',
#                             'locations': 'GA',
#                             'name': "Robert E. Lee's Birthday",
#                             'states': [{'abbrev': 'GA',
#                                         'exception': None,
#                                         'id': 13,
#                                         'iso': 'us-ga',
#                                         'name': 'Georgia'}],
#                             'type': ['Local holiday']},
#                            {'country': {'id': 'us', 'name': 'United States'},
#                             'date': {'datetime': {'day': 18,
#                                                   'month': 1,
#                                                   'year': 2010},
#                                      'iso': '2010-01-18'},
#                             'description': 'Robert E. Lee’s birthday is an '
#                                            'annual official state holiday that '
#                                            'is shared with Martin Luther '
#                                            'King’s birthday in some parts of '
#                                            'the US.',
#                             'locations': 'AL',
#                             'name': "Robert E. Lee's Birthday",
#                             'states': [{'abbrev': 'AL',
#                                         'exception': None,
#                                         'id': 1,
#                                         'iso': 'us-al',
#                                         'name': 'Alabama'}],
#                             'type': ['Local holiday']},
#                            {'country': {'id': 'us', 'name': 'United States'},
#                             'date': {'datetime': {'day': 18,
#                                                   'month': 1,
#                                                   'year': 2010},
#                                      'iso': '2010-01-18'},
#                             'description': 'Robert E. Lee’s birthday is an '
#                                            'annual official state holiday that '
#                                            'is shared with Martin Luther '
#                                            'King’s birthday in some parts of '
#                                            'the US.',
#                             'locations': 'AR',
#                             'name': "Robert E. Lee's Birthday",
#                             'states': [{'abbrev': 'AR',
#                                         'exception': None,
#                                         'id': 5,
#                                         'iso': 'us-ar',
#                                         'name': 'Arkansas'}],
#                             'type': ['Local holiday']},
#                            {'country': {'id': 'us', 'name': 'United States'},
#                             'date': {'datetime': {'day': 18,
#                                                   'month': 1,
#                                                   'year': 2010},
#                                      'iso': '2010-01-18'},
#                             'description': 'Robert E. Lee’s birthday is an '
#                                            'annual official state holiday that '
#                                            'is shared with Martin Luther '
#                                            'King’s birthday in some parts of '
#                                            'the US.',
#                             'locations': 'MS',
#                             'name': "Robert E. Lee's Birthday",
#                             'states': [{'abbrev': 'MS',
#                                         'exception': None,
#                                         'id': 28,
#                                         'iso': 'us-ms',
#                                         'name': 'Mississippi'}],
#                             'type': ['Local holiday']},
#                            {'country': {'id': 'us', 'name': 'United States'},
#                             'date': {'datetime': {'day': 18,
#                                                   'month': 1,
#                                                   'year': 2010},
#                                      'iso': '2010-01-18'},
#                             'description': 'Robert E. Lee’s birthday is an '
#                                            'annual official state holiday that '
#                                            'is shared with Martin Luther '
#                                            'King’s birthday in some parts of '
#                                            'the US.',
#                             'locations': 'All',
#                             'name': "Robert E. Lee's Birthday",
#                             'states': 'All',
#                             'type': ['Local holiday']},
#                            {'country': {'id': 'us', 'name': 'United States'},
#                             'date': {'datetime': {'day': 18,
#                                                   'month': 1,
#                                                   'year': 2010},
#                                      'iso': '2010-01-18'},
#                             'description': 'Idaho Human Rights Day is a state '
#                                            'holiday in Idaho, the United '
#                                            'States, on the third Monday of '
#                                            'January.',
#                             'locations': 'ID',
#                             'name': 'Idaho Human Rights Day',
#                             'states': [{'abbrev': 'ID',
#                                         'exception': None,
#                                         'id': 15,
#                                         'iso': 'us-id',
#                                         'name': 'Idaho'}],
#                             'type': ['Local holiday']},
#                            {'country': {'id': 'us', 'name': 'United States'},
#                             'date': {'datetime': {'day': 18,
#                                                   'month': 1,
#                                                   'year': 2010},
#                                      'iso': '2010-01-18'},
#                             'description': 'Civil Rights Day is on the third '
#                                            'Monday of January in Arizona and '
#                                            'New Hampshire. It honors civil '
#                                            'rights activists such as Martin '
#                                            'Luther King Jr.',
#                             'locations': 'NH',
#                             'name': 'Civil Rights Day',
#                             'states': [{'abbrev': 'NH',
#                                         'exception': None,
#                                         'id': 33,
#                                         'iso': 'us-nh',
#                                         'name': 'New Hampshire'}],
#                             'type': ['Local holiday']},
#                            {'country': {'id': 'us', 'name': 'United States'},
#                             'date': {'datetime': {'day': 18,
#                                                   'month': 1,
#                                                   'year': 2010},
#                                      'iso': '2010-01-18'},
#                             'description': 'Civil Rights Day is on the third '
#                                            'Monday of January in Arizona and '
#                                            'New Hampshire. It honors civil '
#                                            'rights activists such as Martin '
#                                            'Luther King Jr.',
#                             'locations': 'AZ',
#                             'name': 'Civil Rights Day',
#                             'states': [{'abbrev': 'AZ',
#                                         'exception': None,
#                                         'id': 4,
#                                         'iso': 'us-az',
#                                         'name': 'Arizona'}],
#                             'type': ['Local holiday']},
#                            {'country': {'id': 'us', 'name': 'United States'},
#                             'date': {'datetime': {'day': 19,
#                                                   'month': 1,
#                                                   'year': 2010},
#                                      'iso': '2010-01-19'},
#                             'description': 'Robert E. Lee’s birthday is an '
#                                            'annual official state holiday that '
#                                            'is shared with Martin Luther '
#                                            'King’s birthday in some parts of '
#                                            'the US.',
#                             'locations': 'FL',
#                             'name': "Robert E. Lee's Birthday",
#                             'states': [{'abbrev': 'FL',
#                                         'exception': None,
#                                         'id': 12,
#                                         'iso': 'us-fl',
#                                         'name': 'Florida'}],
#                             'type': ['Local holiday']},
#                            {'country': {'id': 'us', 'name': 'United States'},
#                             'date': {'datetime': {'day': 19,
#                                                   'month': 1,
#                                                   'year': 2010},
#                                      'iso': '2010-01-19'},
#                             'description': 'On Confederate Memorial Day '
#                                            'remembers the soldiers who died '
#                                            'fighting for the Confederate '
#                                            'States of America during the '
#                                            'American Civil War (1861-1865). It '
#                                            'is a state holiday in some parts '
#                                            'of the United States.',
#                             'locations': 'TX',
#                             'name': "Confederate Heroes' Day",
#                             'states': [{'abbrev': 'TX',
#                                         'exception': None,
#                                         'id': 48,
#                                         'iso': 'us-tx',
#                                         'name': 'Texas'}],
#                             'type': ['Local holiday']},
#                            {'country': {'id': 'us', 'name': 'United States'},
#                             'date': {'datetime': {'day': 27,
#                                                   'month': 1,
#                                                   'year': 2010},
#                                      'iso': '2010-01-27'},
#                             'description': "The United Nations' (UN) "
#                                            'International Day of Commemoration '
#                                            'in Memory of the Victims of the '
#                                            'Holocaust remembers those who died '
#                                            'and suffered during the Holocaust '
#                                            'before and during World War II. It '
#                                            'is on January 27 each year.',
#                             'locations': 'All',
#                             'name': 'International Day of Commemoration in '
#                                     'Memory of the Victims of the Holocaust',
#                             'states': 'All',
#                             'type': ['United Nations observance']},
#                            {'country': {'id': 'us', 'name': 'United States'},
#                             'date': {'datetime': {'day': 29,
#                                                   'month': 1,
#                                                   'year': 2010},
#                                      'iso': '2010-01-29'},
#                             'description': 'Kansas Day is an annual observance '
#                                            "that commemorates the state's "
#                                            'admission to the Union in 1861.',
#                             'locations': 'All',
#                             'name': 'Kansas Day',
#                             'states': 'All',
#                             'type': ['Observance']},
#                            {'country': {'id': 'us', 'name': 'United States'},
#                             'date': {'datetime': {'day': 30,
#                                                   'month': 1,
#                                                   'year': 2010},
#                                      'iso': '2010-01-30'},
#                             'description': 'Tu B’Shevat is known as the “New '
#                                            'Year for Trees”, is a Jewish '
#                                            'festival similar to Arbor Day.',
#                             'locations': 'All',
#                             'name': "Tu Bishvat/Tu B'Shevat",
#                             'states': 'All',
#                             'type': ['Hebrew']},
#                            {'country': {'id': 'us', 'name': 'United States'},
#                             'date': {'datetime': {'day': 31,
#                                                   'month': 1,
#                                                   'year': 2010},
#                                      'iso': '2010-01-31'},
#                             'description': 'World Leprosy Day brings awareness '
#                                            "of leprosy, also known as Hansen's "
#                                            'disease, and ways to prevent the '
#                                            'disease.',
#                             'locations': 'All',
#                             'name': 'World Leprosy Day',
#                             'states': 'All',
#                             'type': ['Worldwide observance']},
#                            {'country': {'id': 'us', 'name': 'United States'},
#                             'date': {'datetime': {'day': 1,
#                                                   'month': 2,
#                                                   'year': 2010},
#                                      'iso': '2010-02-01'},
#                             'description': 'National Freedom Day in the United '
#                                            'States is observed on February 1 '
#                                            'each year.',
#                             'locations': 'All',
#                             'name': 'National Freedom Day',
#                             'states': 'All',
#                             'type': ['Observance']},
#                            {'country': {'id': 'us', 'name': 'United States'},
#                             'date': {'datetime': {'day': 1,
#                                                   'month': 2,
#                                                   'year': 2010},
#                                      'iso': '2010-02-01'},
#                             'description': 'First Day of Black History Month '
#                                            'is a annual monthly observance in '
#                                            'the USA',
#                             'locations': 'All',
#                             'name': 'First Day of Black History Month',
#                             'states': 'All',
#                             'type': ['Observance']},
#                            {'country': {'id': 'us', 'name': 'United States'},
#                             'date': {'datetime': {'day': 2,
#                                                   'month': 2,
#                                                   'year': 2010},
#                                      'iso': '2010-02-02'},
#                             'description': 'World Wetlands Day raises '
#                                            'awareness about the important role '
#                                            'that the wetlands play in the '
#                                            'environment and in our lives.',
#                             'locations': 'All',
#                             'name': 'World Wetlands Day',
#                             'states': 'All',
#                             'type': ['Worldwide observance']},
#                            {'country': {'id': 'us', 'name': 'United States'},
#                             'date': {'datetime': {'day': 2,
#                                                   'month': 2,
#                                                   'year': 2010},
#                                      'iso': '2010-02-02'},
#                             'description': 'Many people in the United States '
#                                            'observe Groundhog Day on February '
#                                            '2.',
#                             'locations': 'All',
#                             'name': 'Groundhog Day',
#                             'states': 'All',
#                             'type': ['Observance']},
#                            {'country': {'id': 'us', 'name': 'United States'},
#                             'date': {'datetime': {'day': 4,
#                                                   'month': 2,
#                                                   'year': 2010},
#                                      'iso': '2010-02-04'},
#                             'description': 'World Cancer Day is an annual '
#                                            'global event on February 4 to '
#                                            'raise people’s awareness of '
#                                            'cancer.',
#                             'locations': 'All',
#                             'name': 'World Cancer Day',
#                             'states': 'All',
#                             'type': ['United Nations observance']},
#                            {'country': {'id': 'us', 'name': 'United States'},
#                             'date': {'datetime': {'day': 4,
#                                                   'month': 2,
#                                                   'year': 2010},
#                                      'iso': '2010-02-04'},
#                             'description': 'The life of American civil rights '
#                                            'leader Rosa Parks is celebrated in '
#                                            'the United States on either '
#                                            'February 4 or December 1.',
#                             'locations': 'CA',
#                             'name': 'Rosa Parks Day',
#                             'states': [{'abbrev': 'CA',
#                                         'exception': None,
#                                         'id': 7,
#                                         'iso': 'us-ca',
#                                         'name': 'California'}],
#                             'type': ['Local observance']},
#                            {'country': {'id': 'us', 'name': 'United States'},
#                             'date': {'datetime': {'day': 5,
#                                                   'month': 2,
#                                                   'year': 2010},
#                                      'iso': '2010-02-05'},
#                             'description': 'National Wear Red Day® raises '
#                                            'public awareness of heart disease '
#                                            'in women and ways to avoid and '
#                                            'combat this problem.',
#                             'locations': 'All',
#                             'name': 'National Wear Red Day',
#                             'states': 'All',
#                             'type': ['Observance']},
#                            {'country': {'id': 'us', 'name': 'United States'},
#                             'date': {'datetime': {'day': 6,
#                                                   'month': 2,
#                                                   'year': 2010},
#                                      'iso': '2010-02-06'},
#                             'description': 'The International Day of Zero '
#                                            'Tolerance for Female Genital '
#                                            'Mutilation is an awareness '
#                                            'campaign to end a harmful practice '
#                                            'that violates girls’ and women’s '
#                                            'rights.',
#                             'locations': 'All',
#                             'name': 'International Day of Zero Tolerance for '
#                                     'Female Genital Mutilation',
#                             'states': 'All',
#                             'type': ['United Nations observance']},
#                            {'country': {'id': 'us', 'name': 'United States'},
#                             'date': {'datetime': {'day': 7,
#                                                   'month': 2,
#                                                   'year': 2010},
#                                      'iso': '2010-02-07'},
#                             'description': 'The Super Bowl is the championship '
#                                            'game of the National Football '
#                                            'League (NFL) in the United States. '
#                                            'It is played every year in '
#                                            'February.',
#                             'locations': 'All',
#                             'name': 'Super Bowl',
#                             'states': 'All',
#                             'type': ['Sporting event']},
#                            {'country': {'id': 'us', 'name': 'United States'},
#                             'date': {'datetime': {'day': 11,
#                                                   'month': 2,
#                                                   'year': 2010},
#                                      'iso': '2010-02-11'},
#                             'description': 'Maha Shivaratri is a Hindu holiday '
#                                            'in the USA',
#                             'locations': 'All',
#                             'name': 'Maha Shivaratri',
#                             'states': 'All',
#                             'type': ['Hinduism']},
#                            {'country': {'id': 'us', 'name': 'United States'},
#                             'date': {'datetime': {'day': 12,
#                                                   'month': 2,
#                                                   'year': 2010},
#                                      'iso': '2010-02-12'},
#                             'description': 'Lincoln’s Birthday is observed in '
#                                            'the United States in honor of '
#                                            'Abraham Lincoln, who was the '
#                                            'nation’s 16th president and was '
#                                            'known as the Great Emancipator.',
#                             'locations': 'CT, IL, NJ, NY, MO',
#                             'name': "Lincoln's Birthday",
#                             'states': [{'abbrev': 'CT',
#                                         'exception': None,
#                                         'id': 9,
#                                         'iso': 'us-ct',
#                                         'name': 'Connecticut'},
#                                        {'abbrev': 'IL',
#                                         'exception': None,
#                                         'id': 16,
#                                         'iso': 'us-il',
#                                         'name': 'Illinois'},
#                                        {'abbrev': 'NJ',
#                                         'exception': None,
#                                         'id': 34,
#                                         'iso': 'us-nj',
#                                         'name': 'New Jersey'},
#                                        {'abbrev': 'NY',
#                                         'exception': None,
#                                         'id': 36,
#                                         'iso': 'us-ny',
#                                         'name': 'New York'},
#                                        {'abbrev': 'MO',
#                                         'exception': None,
#                                         'id': 29,
#                                         'iso': 'us-mo',
#                                         'name': 'Missouri'}],
#                             'type': ['Local holiday']},
#                            {'country': {'id': 'us', 'name': 'United States'},
#                             'date': {'datetime': {'day': 14,
#                                                   'month': 2,
#                                                   'year': 2010},
#                                      'iso': '2010-02-14'},
#                             'description': "Valentine's Day is an occasion to "
#                                            'celebrate romantic love.',
#                             'locations': 'All',
#                             'name': "Valentine's Day",
#                             'states': 'All',
#                             'type': ['Observance']},
#                            {'country': {'id': 'us', 'name': 'United States'},
#                             'date': {'datetime': {'day': 14,
#                                                   'month': 2,
#                                                   'year': 2010},
#                                      'iso': '2010-02-14'},
#                             'description': 'Statehood Day is a local '
#                                            'observance in the USA',
#                             'locations': 'AZ',
#                             'name': 'Statehood Day',
#                             'states': [{'abbrev': 'AZ',
#                                         'exception': None,
#                                         'id': 4,
#                                         'iso': 'us-az',
#                                         'name': 'Arizona'}],
#                             'type': ['Local observance']},
#                            {'country': {'id': 'us', 'name': 'United States'},
#                             'date': {'datetime': {'day': 14,
#                                                   'month': 2,
#                                                   'year': 2010},
#                                      'iso': '2010-02-14'},
#                             'description': 'Chinese New Year marks the first '
#                                            'day of the New Year in the Chinese '
#                                            'calendar.',
#                             'locations': 'All',
#                             'name': 'Chinese New Year',
#                             'states': 'All',
#                             'type': ['Observance']},
#                            {'country': {'id': 'us', 'name': 'United States'},
#                             'date': {'datetime': {'day': 15,
#                                                   'month': 2,
#                                                   'year': 2010},
#                                      'iso': '2010-02-15'},
#                             'description': "Washington's Birthday, or "
#                                            "Presidents' Day, honors the life "
#                                            'and work of the first president of '
#                                            'the United States, George '
#                                            'Washington.',
#                             'locations': 'All except DE, GA, IN, IA, KS, KY, '
#                                          'LA, NM, NC, RI, WI',
#                             'name': "Presidents' Day",
#                             'states': [{'abbrev': 'AL',
#                                         'exception': None,
#                                         'id': 1,
#                                         'iso': 'us-al',
#                                         'name': 'Alabama'},
#                                        {'abbrev': 'AK',
#                                         'exception': None,
#                                         'id': 2,
#                                         'iso': 'us-ak',
#                                         'name': 'Alaska'},
#                                        {'abbrev': 'AZ',
#                                         'exception': None,
#                                         'id': 4,
#                                         'iso': 'us-az',
#                                         'name': 'Arizona'},
#                                        {'abbrev': 'AR',
#                                         'exception': None,
#                                         'id': 5,
#                                         'iso': 'us-ar',
#                                         'name': 'Arkansas'},
#                                        {'abbrev': 'CA',
#                                         'exception': None,
#                                         'id': 7,
#                                         'iso': 'us-ca',
#                                         'name': 'California'},
#                                        {'abbrev': 'CO',
#                                         'exception': None,
#                                         'id': 8,
#                                         'iso': 'us-co',
#                                         'name': 'Colorado'},
#                                        {'abbrev': 'CT',
#                                         'exception': None,
#                                         'id': 9,
#                                         'iso': 'us-ct',
#                                         'name': 'Connecticut'},
#                                        {'abbrev': 'DC',
#                                         'exception': None,
#                                         'id': 11,
#                                         'iso': 'us-dc',
#                                         'name': 'District of Columbia'},
#                                        {'abbrev': 'FL',
#                                         'exception': None,
#                                         'id': 12,
#                                         'iso': 'us-fl',
#                                         'name': 'Florida'},
#                                        {'abbrev': 'HI',
#                                         'exception': None,
#                                         'id': 14,
#                                         'iso': 'us-hi',
#                                         'name': 'Hawaii'},
#                                        {'abbrev': 'ID',
#                                         'exception': None,
#                                         'id': 15,
#                                         'iso': 'us-id',
#                                         'name': 'Idaho'},
#                                        {'abbrev': 'IL',
#                                         'exception': None,
#                                         'id': 16,
#                                         'iso': 'us-il',
#                                         'name': 'Illinois'},
#                                        {'abbrev': 'ME',
#                                         'exception': None,
#                                         'id': 22,
#                                         'iso': 'us-me',
#                                         'name': 'Maine'},
#                                        {'abbrev': 'MD',
#                                         'exception': None,
#                                         'id': 24,
#                                         'iso': 'us-md',
#                                         'name': 'Maryland'},
#                                        {'abbrev': 'MA',
#                                         'exception': None,
#                                         'id': 25,
#                                         'iso': 'us-ma',
#                                         'name': 'Massachusetts'},
#                                        {'abbrev': 'MI',
#                                         'exception': None,
#                                         'id': 26,
#                                         'iso': 'us-mi',
#                                         'name': 'Michigan'},
#                                        {'abbrev': 'MN',
#                                         'exception': None,
#                                         'id': 27,
#                                         'iso': 'us-mn',
#                                         'name': 'Minnesota'},
#                                        {'abbrev': 'MS',
#                                         'exception': None,
#                                         'id': 28,
#                                         'iso': 'us-ms',
#                                         'name': 'Mississippi'},
#                                        {'abbrev': 'MO',
#                                         'exception': None,
#                                         'id': 29,
#                                         'iso': 'us-mo',
#                                         'name': 'Missouri'},
#                                        {'abbrev': 'MT',
#                                         'exception': None,
#                                         'id': 30,
#                                         'iso': 'us-mt',
#                                         'name': 'Montana'},
#                                        {'abbrev': 'NE',
#                                         'exception': None,
#                                         'id': 31,
#                                         'iso': 'us-ne',
#                                         'name': 'Nebraska'},
#                                        {'abbrev': 'NV',
#                                         'exception': None,
#                                         'id': 32,
#                                         'iso': 'us-nv',
#                                         'name': 'Nevada'},
#                                        {'abbrev': 'NH',
#                                         'exception': None,
#                                         'id': 33,
#                                         'iso': 'us-nh',
#                                         'name': 'New Hampshire'},
#                                        {'abbrev': 'NJ',
#                                         'exception': None,
#                                         'id': 34,
#                                         'iso': 'us-nj',
#                                         'name': 'New Jersey'},
#                                        {'abbrev': 'NY',
#                                         'exception': None,
#                                         'id': 36,
#                                         'iso': 'us-ny',
#                                         'name': 'New York'},
#                                        {'abbrev': 'ND',
#                                         'exception': None,
#                                         'id': 38,
#                                         'iso': 'us-nd',
#                                         'name': 'North Dakota'},
#                                        {'abbrev': 'OH',
#                                         'exception': None,
#                                         'id': 40,
#                                         'iso': 'us-oh',
#                                         'name': 'Ohio'},
#                                        {'abbrev': 'OK',
#                                         'exception': None,
#                                         'id': 41,
#                                         'iso': 'us-ok',
#                                         'name': 'Oklahoma'},
#                                        {'abbrev': 'OR',
#                                         'exception': None,
#                                         'id': 42,
#                                         'iso': 'us-or',
#                                         'name': 'Oregon'},
#                                        {'abbrev': 'PA',
#                                         'exception': None,
#                                         'id': 43,
#                                         'iso': 'us-pa',
#                                         'name': 'Pennsylvania'},
#                                        {'abbrev': 'SC',
#                                         'exception': None,
#                                         'id': 45,
#                                         'iso': 'us-sc',
#                                         'name': 'South Carolina'},
#                                        {'abbrev': 'SD',
#                                         'exception': None,
#                                         'id': 46,
#                                         'iso': 'us-sd',
#                                         'name': 'South Dakota'},
#                                        {'abbrev': 'TN',
#                                         'exception': None,
#                                         'id': 47,
#                                         'iso': 'us-tn',
#                                         'name': 'Tennessee'},
#                                        {'abbrev': 'TX',
#                                         'exception': None,
#                                         'id': 48,
#                                         'iso': 'us-tx',
#                                         'name': 'Texas'},
#                                        {'abbrev': 'UT',
#                                         'exception': None,
#                                         'id': 49,
#                                         'iso': 'us-ut',
#                                         'name': 'Utah'},
#                                        {'abbrev': 'VT',
#                                         'exception': None,
#                                         'id': 50,
#                                         'iso': 'us-vt',
#                                         'name': 'Vermont'},
#                                        {'abbrev': 'VA',
#                                         'exception': None,
#                                         'id': 52,
#                                         'iso': 'us-va',
#                                         'name': 'Virginia'},
#                                        {'abbrev': 'WA',
#                                         'exception': None,
#                                         'id': 53,
#                                         'iso': 'us-wa',
#                                         'name': 'Washington'},
#                                        {'abbrev': 'WV',
#                                         'exception': None,
#                                         'id': 54,
#                                         'iso': 'us-wv',
#                                         'name': 'West Virginia'},
#                                        {'abbrev': 'WY',
#                                         'exception': None,
#                                         'id': 56,
#                                         'iso': 'us-wy',
#                                         'name': 'Wyoming'}],
#                             'type': ['National holiday']},
#                            {'country': {'id': 'us', 'name': 'United States'},
#                             'date': {'datetime': {'day': 15,
#                                                   'month': 2,
#                                                   'year': 2010},
#                                      'iso': '2010-02-15'},
# ...
#                                            'in honor of Jesus’ mother Mary, is '
#                                            'a Catholic observance in the '
#                                            'United States.',
#                             'locations': 'All',
#                             'name': 'Feast of Our Lady of Guadalupe',
#                             'states': 'All',
#                             'type': ['Christian']},
#                            {'country': {'id': 'us', 'name': 'United States'},
#                             'date': {'datetime': {'day': 13,
#                                                   'month': 12,
#                                                   'year': 2010},
#                                      'iso': '2010-12-13'},
#                             'description': 'National Guard Birthday is a '
#                                            'observance in the USA',
#                             'locations': 'All',
#                             'name': 'National Guard Birthday',
#                             'states': 'All',
#                             'type': ['Observance']},
#                            {'country': {'id': 'us', 'name': 'United States'},
#                             'date': {'datetime': {'day': 15,
#                                                   'month': 12,
#                                                   'year': 2010},
#                                      'iso': '2010-12-15'},
#                             'description': 'Bill of Rights Day is a observance '
#                                            'in the USA',
#                             'locations': 'All',
#                             'name': 'Bill of Rights Day',
#                             'states': 'All',
#                             'type': ['Observance']},
#                            {'country': {'id': 'us', 'name': 'United States'},
#                             'date': {'datetime': {'day': 17,
#                                                   'month': 12,
#                                                   'year': 2010},
#                                      'iso': '2010-12-17'},
#                             'description': 'December 17 marks Pan American '
#                                            'Aviation Day, which is annually '
#                                            'observed in the United States.',
#                             'locations': 'All',
#                             'name': 'Pan American Aviation Day',
#                             'states': 'All',
#                             'type': ['Observance']},
#                            {'country': {'id': 'us', 'name': 'United States'},
#                             'date': {'datetime': {'day': 17,
#                                                   'month': 12,
#                                                   'year': 2010},
#                                      'iso': '2010-12-17'},
#                             'description': 'The Wright Brothers Day is '
#                                            'annually celebrated in the United '
#                                            'States on December 17 to '
#                                            'commemorate the historic flight '
#                                            'made by Orville and Wilbur Wright '
#                                            'on that date in 1903.',
#                             'locations': 'All',
#                             'name': 'Wright Brothers Day',
#                             'states': 'All',
#                             'type': ['Observance']},
#                            {'country': {'id': 'us', 'name': 'United States'},
#                             'date': {'datetime': {'day': 18,
#                                                   'month': 12,
#                                                   'year': 2010},
#                                      'iso': '2010-12-18'},
#                             'description': 'The United Nations (UN) '
#                                            'International Migrants Day is '
#                                            'celebrated on December 18 each '
#                                            'year.',
#                             'locations': 'All',
#                             'name': 'International Migrants Day',
#                             'states': 'All',
#                             'type': ['United Nations observance']},
#                            {'country': {'id': 'us', 'name': 'United States'},
#                             'date': {'datetime': {'day': 19,
#                                                   'month': 12,
#                                                   'year': 2010},
#                                      'iso': '2010-12-19'},
#                             'description': 'The United Nations Day for '
#                                            'South-South Cooperation is '
#                                            'observed on September 12 each '
#                                            'year.',
#                             'locations': 'All',
#                             'name': 'International Day for South-South '
#                                     'Cooperation',
#                             'states': 'All',
#                             'type': ['United Nations observance']},
#                            {'country': {'id': 'us', 'name': 'United States'},
#                             'date': {'datetime': {'day': 20,
#                                                   'month': 12,
#                                                   'year': 2010},
#                                      'iso': '2010-12-20'},
#                             'description': "The United Nations' (UN) "
#                                            'International Human Solidarity Day '
#                                            'is celebrated on December 20 each '
#                                            'year to raise public awareness on '
#                                            'the importance of solidarity in '
#                                            'fighting poverty.',
#                             'locations': 'All',
#                             'name': 'International Human Solidarity Day',
#                             'states': 'All',
#                             'type': ['United Nations observance']},
#                            {'country': {'id': 'us', 'name': 'United States'},
#                             'date': {'datetime': {'day': 21,
#                                                   'hour': 18,
#                                                   'minute': 38,
#                                                   'month': 12,
#                                                   'second': 27,
#                                                   'year': 2010},
#                                      'iso': '2010-12-21T18:38:27-05:00',
#                                      'timezone': {'offset': '-05:00',
#                                                   'zoneabb': 'EST',
#                                                   'zonedst': 0,
#                                                   'zoneoffset': -18000,
#                                                   'zonetotaloffset': -18000}},
#                             'description': 'December Solstice in the USA (New '
#                                            'York)',
#                             'locations': 'All',
#                             'name': 'December Solstice',
#                             'states': 'All',
#                             'type': ['Season']},
#                            {'country': {'id': 'us', 'name': 'United States'},
#                             'date': {'datetime': {'day': 23,
#                                                   'month': 12,
#                                                   'year': 2010},
#                                      'iso': '2010-12-23'},
#                             'description': "Washington's Birthday, or "
#                                            "Presidents' Day, honors the life "
#                                            'and work of the first president of '
#                                            'the United States, George '
#                                            'Washington.',
#                             'locations': 'IN',
#                             'name': "Washington's Birthday",
#                             'states': [{'abbrev': 'IN',
#                                         'exception': None,
#                                         'id': 17,
#                                         'iso': 'us-in',
#                                         'name': 'Indiana'}],
#                             'type': ['Local holiday']},
#                            {'country': {'id': 'us', 'name': 'United States'},
#                             'date': {'datetime': {'day': 24,
#                                                   'month': 12,
#                                                   'year': 2010},
#                                      'iso': '2010-12-24'},
#                             'description': 'Christmas Day celebrates Jesus '
#                                            "Christ's birth.",
#                             'locations': 'All',
#                             'name': 'Day off for Christmas Day',
#                             'states': 'All',
#                             'type': ['National holiday', 'Christian']},
#                            {'country': {'id': 'us', 'name': 'United States'},
#                             'date': {'datetime': {'day': 24,
#                                                   'month': 12,
#                                                   'year': 2010},
#                                      'iso': '2010-12-24'},
#                             'description': 'Christmas Eve in the United States '
#                                            'is on December 24 each year.',
#                             'locations': 'All',
#                             'name': 'Christmas Eve',
#                             'states': 'All',
#                             'type': ['Observance', 'Christian']},
#                            {'country': {'id': 'us', 'name': 'United States'},
#                             'date': {'datetime': {'day': 24,
#                                                   'month': 12,
#                                                   'year': 2010},
#                                      'iso': '2010-12-24'},
#                             'description': 'Christmas Eve in the United States '
#                                            'is on December 24 each year.',
#                             'locations': 'TX',
#                             'name': 'Christmas Eve',
#                             'states': [{'abbrev': 'TX',
#                                         'exception': None,
#                                         'id': 48,
#                                         'iso': 'us-tx',
#                                         'name': 'Texas'}],
#                             'type': ['Local holiday']},
#                            {'country': {'id': 'us', 'name': 'United States'},
#                             'date': {'datetime': {'day': 25,
#                                                   'month': 12,
#                                                   'year': 2010},
#                                      'iso': '2010-12-25'},
#                             'description': 'Christmas Day celebrates Jesus '
#                                            "Christ's birth.",
#                             'locations': 'All',
#                             'name': 'Christmas Day',
#                             'states': 'All',
#                             'type': ['National holiday', 'Christian']},
#                            {'country': {'id': 'us', 'name': 'United States'},
#                             'date': {'datetime': {'day': 26,
#                                                   'month': 12,
#                                                   'year': 2010},
#                                      'iso': '2010-12-26'},
#                             'description': 'Kwanzaa is a week-long holiday '
#                                            'honoring the culture and '
#                                            'traditions of African people and '
#                                            'their descendants worldwide, '
#                                            'especially in the United States.',
#                             'locations': 'All',
#                             'name': 'Kwanzaa (first day)',
#                             'states': 'All',
#                             'type': ['Observance']},
#                            {'country': {'id': 'us', 'name': 'United States'},
#                             'date': {'datetime': {'day': 26,
#                                                   'month': 12,
#                                                   'year': 2010},
#                                      'iso': '2010-12-26'},
#                             'description': 'Some states in the United States '
#                                            'observe the Day after Christmas '
#                                            'Day as a public holiday.',
#                             'locations': 'TX',
#                             'name': 'Day After Christmas Day',
#                             'states': [{'abbrev': 'TX',
#                                         'exception': None,
#                                         'id': 48,
#                                         'iso': 'us-tx',
#                                         'name': 'Texas'}],
#                             'type': ['Local holiday']},
#                            {'country': {'id': 'us', 'name': 'United States'},
#                             'date': {'datetime': {'day': 31,
#                                                   'month': 12,
#                                                   'year': 2010},
#                                      'iso': '2010-12-31'},
#                             'description': "New Year's Day is the first day of "
#                                            'the Gregorian calendar, which is '
#                                            'widely used in many countries such '
#                                            'as the USA.',
#                             'locations': 'All',
#                             'name': "Day off for New Year's Day",
#                             'states': 'All',
#                             'type': ['National holiday']},
#                            {'country': {'id': 'us', 'name': 'United States'},
#                             'date': {'datetime': {'day': 31,
#                                                   'month': 12,
#                                                   'year': 2010},
#                                      'iso': '2010-12-31'},
#                             'description': "New Year's Eve is the last day of "
#                                            'the year in the Gregorian '
#                                            'calendar. Many parties to welcome '
#                                            'the New Year are held in in the '
#                                            "United States on New Year's Eve.",
#                             'locations': 'All',
#                             'name': "New Year's Eve",
#                             'states': 'All',
#                             'type': ['Observance']}]}}
# y = -3386.33x + 1100198.88 -0.06
# Temperature Holiday: y = -4312.63x + 1237890.05 R-value: -0.07142104559342675
# Temperature No Holiday: y = -2855.28x + 1082037.67 R-value: -0.052139268364334156
# y = 12788.11x + 1003367.22 0.01
# Fuel Price Holiday:  y = 13767.03x + 1143889.27 R-value: 0.01
# Fuel Price No Holiday: y = 21461.13x + 963340.24 R-value: 0.02
# y = -31790.24x + 1300593.84 -0.10556729909435844
# Unemployment Holiday:  y = -30508.36x + 1433769.07 R-value: -0.08
# Unemployment No Holiday: y = -32089.32x + 1292201.9 R-value: -0.11
# y = -1029.85x + 1222997.6 -0.07176458496680631
# CPI Holiday:  y = -1453.45x + 1436525.2 R-value: -0.08
# CPI No Holiday: y = -994.81x + 1206386.27 R-value: -0.07

# %%
import pandas as pd
import matplotlib.pyplot as plt
import scipy.stats as st
import numpy as np
#data = pd.read_csv("Dataset/final_df.csv")
data = walmart_holiday
#total_percent = pd.read_csv("Dataset/total_percent.csv")
total_percent = walmart_ttl.data
#holi_sum = pd.read_csv("Dataset/summary_holiday.csv")
holi_sum = holiday_summary.data
#unrate_ave = pd.read_csv("Dataset/rate_avg_holiday.csv")
unrate_ave = rate_holiday.data
#temp_ave = pd.read_csv("Dataset/temp_avg_is.csv")
temp_ave = temp_is.data
#unrate_avg = pd.read_csv("Dataset/rate_avg.csv")
unrate_avg = rate.data
#temp_total = pd.read_csv("Dataset/temp_ttl.csv")
temp_total = temp_ttl.data
#rate_total = pd.read_csv("Dataset/rate_ttl.csv")
rate_total = rate_ttl.data
weeksales = pd.read_csv("Weekly Sales.csv")

# %%
holi_sum["Weekly_Sales"] = holi_sum["Weekly_Sales"].replace('[\$,]', '', regex=True).astype(float)
unrate_ave["Weekly_Sales"] = unrate_ave["Weekly_Sales"].replace('[\$,]', '', regex=True).astype(float)
temp_ave["Weekly_Sales"] = temp_ave["Weekly_Sales"].replace('[\$,]', '', regex=True).astype(float)
unrate_avg["Weekly_Sales"] = unrate_avg["Weekly_Sales"].replace('[\$,]', '', regex=True).astype(float)
temp_total["Weekly_Sales"] = temp_total["Weekly_Sales"].replace('[\$,]', '', regex=True).astype(float)
rate_total["Weekly_Sales"] = rate_total["Weekly_Sales"].replace('[\$,]', '', regex=True).astype(float)

# %%
#BAR GRAPH of TOTAL WEEKLY SALES by UNEMPLOYMENT RANGE
total_sales = rate_total["Weekly_Sales"]
rate_categories = rate_total.index
plt.bar(rate_categories, total_sales)
plt.title("Total Weekly Sales by Unemployment Range")
plt.xlabel("Temperature Ranges")
plt.ylabel("Weekly Sales ($)")
plt.tight_layout()
plt.xticks(rotation=45)
plt.grid(axis="y")
plt.savefig("Figures/fig1.png")
plt.show()

# %%
#PIE CHART TOTAL SALES BY UNEMPLOYMENT CATEGORY
total_sales = rate_total["Weekly_Sales"]
rate_categories = rate_total.index
explode = (0,1)
plt.title("Total Sales by Unemployment Range")
plt.pie(total_sales, labels = rate_categories, shadow = True,autopct='%1.1f%%')
plt.legend()
plt.axis("equal")
plt.savefig("Figures/fig2.png")

# %%
#PIE CHART OF TOTAL SALES BY TEMP CATEGORY
total_sales = temp_total["Weekly_Sales"]
temp_categories = temp_total.index
explode = (0,1)
plt.title("Total % Sales by Temperature Category")
plt.pie(total_sales, labels=temp_categories,shadow = True,autopct='%1.1f%%')
plt.legend()
plt.axis("equal")
plt.savefig("Figures/fig3.png")

# %%
#BAR GRAPH TOTAL WEEKLY SALES BY TEMPERATURE CATEGORY
total_sales = temp_total["Weekly_Sales"]
temp_categories = temp_total.index
plt.bar(temp_categories, total_sales)
plt.title("Total Weekly Sales by Temperature Range")
plt.xlabel("Temperature Ranges")
plt.ylabel("Weekly Sales($)")
plt.tight_layout()
plt.xticks(rotation=45)
plt.grid(axis="y")
plt.savefig("Figures/fig4.png")

# %%
#BAR GRAPH OF AVERAGE WEEKLY SALES BY UNEMPLOYMENT RATE
weekly_sales = unrate_avg["Weekly_Sales"]
unemp_categories = unrate_avg.index
plt.title("Average Weekly Sales by Unemployment Rate Range")
plt.bar(unemp_categories, weekly_sales, color="blue")
plt.xlabel("Unemployment Rate Ranges")
plt.ylabel("Weekly Sales ($)")
plt.tight_layout()
plt.xticks(rotation=45)
plt.grid()
plt.savefig("Figures/fig5.png")
plt.show()

# %%
regular_sales_total = data.loc[data["Is Holiday"]=="No Holiday"]["Weekly_Sales"].sum()
holiday_sales_total = data.loc[data["Is Holiday"]=="Holiday"]["Weekly_Sales"].sum()
weekly_sales = data["Weekly_Sales"]
ave_temperature = data["Temperature C"]
ave_fuel_price = data["Fuel_Price"]
un_rate = data["Unemployment"]
cpi = data["CPI"]
store_number = data["Store"]

# %%
#PIE CHART TOTAL HOLIDAY AND NON HOLIDAY SALES
regular_sales_total
holiday_sales_total

types = ["Regular Sales","Holiday Sales"]
sales = [regular_sales_total, holiday_sales_total]
explode = (0,1)
plt.title("Holiday Sales vs. Regiular Sales")
plt.pie(sales, labels = types, shadow = True,autopct='%1.1f%%')
plt.legend()
plt.axis("equal")
plt.savefig("Figures/fig6.png")

# %%
#SCATTER PLOT BY AVERAGE TEMPERATURE
ave_temperature=data["Temperature C"]
weekly_sales=data["Weekly_Sales"]

plt.title("All Weekly Sales vs. Temperature")
plt.xlabel("Average Temperature (C)")
plt.ylabel("Weekly Sales ($)")
plt.grid()
plt.scatter(ave_temperature, weekly_sales, marker="o", color = "red",edgecolors="black")
plt.ticklabel_format(style='plain')
slope, intercept, r_value, p_value, std_err = st.linregress(ave_temperature, weekly_sales)
best_fit = slope*ave_temperature+intercept
plt.plot(ave_temperature,best_fit)
plt.figure(figsize=(20,10)) 
plt.tight_layout()
plt.savefig("Figures/fig7.png")

# %%
#SCATTER by FUEL PRICE
ave_fuel_price = data["Fuel_Price"]
weekly_sales=data["Weekly_Sales"]

plt.title("All Weekly Sales vs. Fuel Price")
plt.xlabel("Average Weekly Fuel Price ($)")
plt.ylabel("Weekly Sales ($)")
plt.tight_layout()
plt.grid()
plt.scatter(ave_fuel_price, weekly_sales, marker="o", color="red",edgecolors="black")
plt.ticklabel_format(style='plain')
slope, intercept, r_value, p_value, std_err = st.linregress(ave_fuel_price, weekly_sales)
best_fit = slope*ave_fuel_price+intercept
plt.plot(ave_fuel_price,best_fit)
plt.savefig("Figures/fig8.png")

# %%
unrateave = unrate_ave.reset_index(drop=False)

# %%
#AVERAGE WEEKLY SALES FOR EACH HOLIDAY BY UNEMPLOYMENT CATEGORY
bar_width = 0.15
fig, ax = plt.subplots(figsize=(12, 8))
r1 = np.arange(len(unrateave["Unemployment Category"].unique()))
r2 = [x + bar_width for x in r1]
r3 = [x + bar_width for x in r2]
r4 = [x + bar_width for x in r3]
r5 = [x + bar_width for x in r4]
b1 = plt.bar(r1, unrateave.loc[unrateave["Holiday Name"] == 'Christmas', 'Weekly_Sales'],width=bar_width, label="Christmas")
b2 = plt.bar(r2, unrateave.loc[unrateave["Holiday Name"] == 'Independence Day', 'Weekly_Sales'],width=bar_width, label="Independence Day")
b3 = plt.bar(r3, unrateave.loc[unrateave["Holiday Name"] == "New Year's Day", 'Weekly_Sales'],width=bar_width, label = "New Year")
b4 = plt.bar(r4, unrateave.loc[unrateave["Holiday Name"] == 'Thanksgiving Day', 'Weekly_Sales'],width=bar_width, label = "Thanksgiving")
b3 = plt.bar(r5, unrateave.loc[unrateave["Holiday Name"] == 'No Holiday', 'Weekly_Sales'],width=bar_width, label = "No Holiday")
#ax.set_xticks(x + bar_width / 5)
plt.xticks([r + bar_width for r in range(len(unrateave["Unemployment Category"].unique()))], ['Low: <6%', 'Normal: 6%-9%', 'High: >9%'],fontsize=15)
plt.xlabel("Unemployment Rate Range")
plt.title("Weekly Sales For Each Holiday by Unemployment",fontsize=20)
plt.ylabel("Weekly Sales ($)",fontsize=20)
plt.xlabel("Unemployment Category",fontsize=20)
ax.legend()
plt.tight_layout()
plt.grid(axis="y")
plt.savefig("Figures/fig9.png")

# %%
tempave = temp_ave.reset_index(drop=False)

# %%
#GROUPED BAR GRAPH WEEKLY SALES BY TEMPERATURE CATEGORY FOR HOLIDAYS AND NON NOLIDAYS
bar_width = 0.4
fig, ax = plt.subplots(figsize=(12, 8))
r1 = np.arange(len(tempave["Temp Category"].unique()))
r2 = [x + bar_width for x in r1]
b1 = ax.bar(r1, tempave.loc[tempave["Is Holiday"] == 'Holiday', 'Weekly_Sales'],width=bar_width, label="Holiday")
b2 = ax.bar(r2, tempave.loc[tempave["Is Holiday"] == 'No Holiday', 'Weekly_Sales'],width=bar_width, label="Non Holiday")
#ax.set_xticks(x + bar_width/2)
plt.xticks([r + bar_width for r in range(len(tempave["Temp Category"].unique()))], ["<-10°C","-10°C to -1°C","0°C to 9°C","10°C to 19°C","20°C to 29°C","≥30°C"])
#ax.set_xticklabels(["<-10°C","-10°C to -1°C","0°C to 9°C","10°C to 19°C","20°C to 29°C","≥30°C"])
plt.xlabel("Temperature Ranges",fontsize=20)
plt.ylabel("Weekly Sales ($)",fontsize=20)
plt.title("Weekly Sales by Temperature Category for Holiday and Non Holiday",fontsize=20)
ax.legend()
plt.tight_layout()
plt.grid(axis="y")
plt.savefig("Figures/fig10.png")

# %%
#SCATTER ALL WEEKLY SALES V UNEMPLOYMENT RATE
weekly_sales = data["Weekly_Sales"]
un_rate = data["Unemployment"]
plt.title("All Weekly Sales vs Unemployment")
plt.xlabel("Unemployment Rate (%)")
plt.ylabel("Weekly Sales ($)")
plt.scatter(un_rate, weekly_sales, marker="o", color="red", edgecolor="black")
slope, intercept, r_value, p_value, std_err = st.linregress(un_rate, weekly_sales)
best_fit = slope*un_rate+intercept
plt.plot(un_rate,best_fit)
plt.grid()
plt.tight_layout()
plt.savefig("Figures/fig11.png")

# %%
#SCATTER ALL WEEKLY SALES BY CPI
weekly_sales = data["Weekly_Sales"]
cpi = data["CPI"]
plt.title("All Weekly Sales vs. CPI")
plt.ylabel("Weekly Sales ($)")
plt.xlabel("Consumer Price Index")
plt.tight_layout()
plt.scatter(cpi,weekly_sales,marker="o", color="red",edgecolor="black")
slope, intercept, r_value, p_value, std_err = st.linregress(cpi, weekly_sales)
best_fit = slope*cpi+intercept
plt.plot(cpi,best_fit)
plt.grid()
plt.savefig("Figures/fig12.png")

# %%
#BAR GRAPH WEEKLY SALES BY HOLIDAY
plt.bar(holi_sum.index,holi_sum["Weekly_Sales"])
plt.xlabel("Type of Day")
plt.ylabel("Weekly Sales ($)")
plt.xticks(rotation=45)
plt.title("Weekly Sales vs. Day Type")
plt.grid(axis="y")
plt.tight_layout()
plt.savefig("Figures/fig13.png")

# %%
holiday_data = data.loc[data["Is Holiday"] != "No Holiday"]

# %%
#SCATTER HOLIDAY WEEKLY SALES BY FUEL PRICE
ave_fuel_price = holiday_data["Fuel_Price"]
weekly_sales = holiday_data["Weekly_Sales"]

plt.title("Holiday Weekly Sales vs. Fuel Price")
plt.xlabel("Average Weekly Fuel Price ($)")
plt.ylabel("Weekly Sales ($)")
plt.tight_layout()
plt.grid()
plt.scatter(ave_fuel_price, weekly_sales, marker="o", color="red",edgecolors="black")
plt.ticklabel_format(style='plain')
slope, intercept, r_value, p_value, std_err = st.linregress(ave_fuel_price, weekly_sales)
best_fit = slope*ave_fuel_price+intercept
plt.plot(ave_fuel_price,best_fit)
plt.savefig("Figures/fig14.png")

# %%
#SCATTER HOLIDAY WEEKLY SALES BY CPI
weekly_sales = holiday_data["Weekly_Sales"]
cpi = holiday_data["CPI"]
plt.title("Holiday Weekly Sales vs. CPI")
plt.ylabel("Weekly Sales ($)")
plt.xlabel("Consumer Price Index")
plt.tight_layout()
plt.scatter(cpi,weekly_sales,marker="o", color="red",edgecolor="black")
slope, intercept, r_value, p_value, std_err = st.linregress(cpi, weekly_sales)
best_fit = slope*cpi+intercept
plt.plot(cpi,best_fit)
plt.grid()
plt.savefig("Figures/fig15.png")

# %%
#SCATTER HOLIDAY WEEKLY SALES BY UNEMPLOYMENT RATE
weekly_sales = holiday_data["Weekly_Sales"]
un_rate = holiday_data["Unemployment"]
plt.title("Holiday Weekly Sales vs. Unemployment Rate")
plt.xlabel("Unemployment Rate (%)")
plt.ylabel("Weekly Sales ($)")
#plt.xlim(4,15)
#plt.ylim(0,5000000)
plt.scatter(un_rate, weekly_sales, marker="o", color="red", edgecolor="black")
slope, intercept, r_value, p_value, std_err = st.linregress(un_rate, weekly_sales)
best_fit = slope*un_rate+intercept
plt.plot(un_rate,best_fit)
plt.grid()
plt.tight_layout()
plt.savefig("Figures/fig16.png")

# %%
#SCATTER PLOT HOLIDAY WEEKLY SALES BY AVERAGE TEMPERATURE

weekly_sales = holiday_data["Weekly_Sales"]
ave_temperature = holiday_data["Temperature C"]

plt.title("Holiday Weekly Sales vs. Temperature")
plt.xlabel("Average Temperature (C)")
plt.ylabel("Weekly Sales ($)")
#plt.xlim(-50,50)
#plt.ylim(0,100000)
plt.grid()
plt.scatter(ave_temperature, weekly_sales, marker="o", color = "red",edgecolors="black")
plt.ticklabel_format(style='plain')
slope, intercept, r_value, p_value, std_err = st.linregress(ave_temperature, weekly_sales)
best_fit = slope*ave_temperature+intercept
plt.plot(ave_temperature,best_fit)
plt.figure(figsize=(20,10)) 
plt.savefig("Figures/fig17.png")

# %%
#ALL WEEKLY SALES BY TEMPERATURE FOR HOLIDAY AND NON-HOLIDAY

ave_temperature1 = data["Temperature C"]
weekly_sales1 = data["Weekly_Sales"]
weekly_sales2 = data.loc[data["Is Holiday"] != "No Holiday"]["Weekly_Sales"]
ave_temperature2 = data.loc[data["Is Holiday"] != "No Holiday"]["Temperature C"]
plt.tight_layout()
plt.figure(figsize=(20,10)) 
plt.grid()
plt.title("Temperature vs. Weekly Sales",fontsize=30)
plt.xlabel("Average Temperature (C)",fontsize=20)
plt.ylabel("Weekly Sales ($)",fontsize=20)

plt.scatter(ave_temperature1, weekly_sales1, marker="o", color = "blue",edgecolors="black",label="All Days")
plt.scatter(ave_temperature2, weekly_sales2, marker="o", color = "red",edgecolors="black",label = "Holidays")
slope2, intercept2, r_value2, p_value2, std_err2 = st.linregress(ave_temperature2, weekly_sales2)
best_fit2 = slope2*ave_temperature2+intercept2
slope1, intercept1, r_value1, p_value1, std_err1 = st.linregress(ave_temperature1, weekly_sales1)
best_fit1 = slope1*ave_temperature1+intercept1
plt.plot(ave_temperature1,best_fit1,linewidth=5,c="blue")
plt.plot(ave_temperature2,best_fit2,linewidth=5,c="red")
plt.legend()
plt.savefig("Figures/fig18.png")

# %%
#ALL WEEKLY SALES BY UNEMPLOYMENT RATE FOR HOLIDAY AND NON-HOLIDAY

un_rate1 = data["Unemployment"]
weekly_sales1 = data["Weekly_Sales"]
weekly_sales2 = data.loc[data["Is Holiday"] != "No Holiday"]["Weekly_Sales"]
un_rate2 = data.loc[data["Is Holiday"] != "No Holiday"]["Unemployment"]
plt.tight_layout()
plt.figure(figsize=(20,10)) 
plt.grid()
plt.title("Weekly Sales vs. Unemployment Rate",fontsize=30)
plt.xlabel("Unemployment Rate (%)",fontsize=20)
plt.ylabel("Weekly Sales ($)",fontsize=20)

plt.scatter(un_rate1, weekly_sales1, marker="o", color = "blue",edgecolors="black",label="All Days")
plt.scatter(un_rate2, weekly_sales2, marker="o", color = "red",edgecolors="black",label = "Holidays")
slope2, intercept2, r_value2, p_value2, std_err2 = st.linregress(un_rate2, weekly_sales2)
best_fit2 = slope2*un_rate2+intercept2
slope1, intercept1, r_value1, p_value1, std_err1 = st.linregress(un_rate1, weekly_sales1)
best_fit1 = slope1*un_rate1+intercept1
plt.plot(un_rate1,best_fit1,linewidth=5,c="blue")
plt.plot(un_rate2,best_fit2,linewidth=5,c="red")
plt.legend()
plt.savefig("Figures/fig19.png")

# %%
#ALL WEEKLY SALES BY CPI FOR HOLIDAY AND NON-HOLIDAY

cpi1 = data["CPI"]
weekly_sales1 = data["Weekly_Sales"]
weekly_sales2 = data.loc[data["Is Holiday"] != "No Holiday"]["Weekly_Sales"]
cpi2 = data.loc[data["Is Holiday"] != "No Holiday"]["CPI"]
plt.tight_layout()
plt.figure(figsize=(20,10)) 
plt.grid()
plt.title("Weekly Sales vs. CPI",fontsize = 30)
plt.xlabel("Consumer Price Index",fontsize=20)
plt.ylabel("Weekly Sales ($)",fontsize = 20)

plt.scatter(cpi1, weekly_sales1, marker="o", color = "blue",edgecolors="black",label="All Days")
plt.scatter(cpi2, weekly_sales2, marker="o", color = "red",edgecolors="black",label = "Holidays")
slope2, intercept2, r_value2, p_value2, std_err2 = st.linregress(cpi2, weekly_sales2)
best_fit2 = slope2*cpi2+intercept2
slope1, intercept1, r_value1, p_value1, std_err1 = st.linregress(cpi1, weekly_sales1)
best_fit1 = slope1*cpi1+intercept1
plt.plot(cpi1,best_fit1,linewidth=5,c="blue")
plt.plot(cpi2,best_fit2,linewidth=5,c="red")
plt.legend()
plt.savefig("Figures/fig20.png")

# %%
#ALL WEEKLY SALES BY CPI FOR HOLIDAY AND NON-HOLIDAY

fuel1 = data["Fuel_Price"]
weekly_sales1 = data["Weekly_Sales"]
weekly_sales2 = data.loc[data["Is Holiday"] != "No Holiday"]["Weekly_Sales"]
fuel2 = data.loc[data["Is Holiday"] != "No Holiday"]["Fuel_Price"]
plt.tight_layout()
plt.figure(figsize=(20,10)) 
plt.grid()
plt.title("Weekly Sales vs. Fuel Price",fontsize=30)
plt.xlabel("Fuel Price ($)",fontsize=20)
plt.ylabel("Weekly Sales ($)",fontsize = 20)

plt.scatter(fuel1, weekly_sales1, marker="o", color = "blue",edgecolors="black",label="All Days")
plt.scatter(fuel2, weekly_sales2, marker="o", color = "red",edgecolors="black",label = "Holidays")
slope2, intercept2, r_value2, p_value2, std_err2 = st.linregress(fuel2, weekly_sales2)
best_fit2 = slope2*fuel2+intercept2
slope1, intercept1, r_value1, p_value1, std_err1 = st.linregress(fuel1, weekly_sales1)
best_fit1 = slope1*fuel1+intercept1
plt.plot(fuel1,best_fit1,linewidth=5,c="blue")
plt.plot(fuel2,best_fit2,linewidth=5,c="red")
plt.legend()
plt.savefig("Figures/fig21.png")

# %%
weeksales
tensales = weeksales.loc[weeksales["Year"]==2010]
elevensales = weeksales.loc[weeksales["Year"]==2011]
twelvesales = weeksales.loc[weeksales["Year"]==2012]

# %%
ten = tensales.groupby("Week")["Weekly_Sales"].sum()
eleven = elevensales.groupby("Week")["Weekly_Sales"].sum()
twelve = twelvesales.groupby("Week")["Weekly_Sales"].sum()
ten
ticks = [1,27,47,52]
labels = ["New Year's Day","Independence Day","Thanksgiving","Christmas Eve"]
plt.xticks(ticks = ticks,labels=labels,rotation=45)
plt.ylabel("Total Weekly Sales ($)")
plt.title("Total Weekly Sales Over Time by Year")
plt.xlabel("Year by Week")
plt.plot(ten,label="2010")
plt.plot(eleven, c="red",label="2011")
plt.plot(twelve,c="green",label="2012")
plt.vlines(1,30000000,80000000)
plt.vlines(27,30000000,80000000)
plt.vlines(47,30000000,80000000)
plt.vlines(51,30000000,80000000)
plt.tight_layout()
plt.legend()
plt.grid()
plt.savefig("Figures/fig22.png")

# %%
#Scatter Holidays by Unemployment Rate
thanks = data.loc[data["Holiday Name"]=="Thanksgiving Day"]
indep = data.loc[data["Holiday Name"]=="Independence Day"]
nyd = data.loc[data["Holiday Name"]=="New Year's Day"]
xmas= data.loc[data["Holiday Name"]=="Christmas"]
plt.scatter(thanks["Unemployment"],thanks["Weekly_Sales"],edgecolor="black", label="Thanksgiving")
plt.scatter(indep["Unemployment"],indep["Weekly_Sales"],c="red",edgecolor="black",label="Independence Day")
plt.scatter(nyd["Unemployment"],nyd["Weekly_Sales"],c="green",edgecolor="black",label="New Year's Day")
plt.scatter(xmas["Unemployment"],xmas["Weekly_Sales"],c="yellow",edgecolor="black",label="New Year's Day")
slopet, interceptt, r_valuet, p_valuet, std_errt = st.linregress(thanks["Unemployment"], thanks["Weekly_Sales"])
best_fitt = slopet*thanks["Unemployment"]+interceptt
plt.plot(thanks["Unemployment"],best_fitt,linewidth=2,c="blue")
slopei, intercepti, r_valuei, p_valuei, std_erri = st.linregress(indep["Unemployment"], indep["Weekly_Sales"])
best_fiti = slopei*indep["Unemployment"]+intercepti
plt.plot(indep["Unemployment"],best_fiti,linewidth=2,c="red")
slopen, interceptn, r_valuen, p_valuen, std_errn = st.linregress(nyd["Unemployment"], nyd["Weekly_Sales"])
best_fitn = slopen*nyd["Unemployment"]+interceptn
plt.plot(nyd["Unemployment"],best_fitn,linewidth=2,c="green")
slopex, interceptx, r_valuex, p_valuex, std_errx = st.linregress(xmas["Unemployment"], xmas["Weekly_Sales"])
best_fitx = slopex*xmas["Unemployment"]+interceptx
plt.plot(xmas["Unemployment"],best_fitx,linewidth=2,c="yellow")
plt.legend()
plt.title("Weekly Sales by Unemployment Rate by Holiday")
plt.ylabel("Weekly Sales ($)")
plt.xlabel("Unemployment Rate (%)")
plt.grid()
plt.tight_layout
plt.savefig("Figures/fig23.png")

# %%
#Scatter Holidays by Temperature
thanks = data.loc[data["Holiday Name"]=="Thanksgiving Day"]
indep = data.loc[data["Holiday Name"]=="Independence Day"]
nyd = data.loc[data["Holiday Name"]=="New Year's Day"]
xmas= data.loc[data["Holiday Name"]=="Christmas"]
plt.scatter(thanks["Temperature C"],thanks["Weekly_Sales"],edgecolor="black", label="Thanksgiving")
plt.scatter(indep["Temperature C"],indep["Weekly_Sales"],c="red",edgecolor="black",label="Independence Day")
plt.scatter(nyd["Temperature C"],nyd["Weekly_Sales"],c="green",edgecolor="black",label="New Year's Day")
plt.scatter(xmas["Temperature C"],xmas["Weekly_Sales"],c="yellow",edgecolor="black",label="New Year's Day")
slopet, interceptt, r_valuet, p_valuet, std_errt = st.linregress(thanks["Temperature C"], thanks["Weekly_Sales"])
best_fitt = slopet*thanks["Temperature C"]+interceptt
plt.plot(thanks["Temperature C"],best_fitt,linewidth=2,c="blue")
slopei, intercepti, r_valuei, p_valuei, std_erri = st.linregress(indep["Temperature C"], indep["Weekly_Sales"])
best_fiti = slopei*indep["Temperature C"]+intercepti
plt.plot(indep["Temperature C"],best_fiti,linewidth=2,c="red")
slopen, interceptn, r_valuen, p_valuen, std_errn = st.linregress(nyd["Temperature C"], nyd["Weekly_Sales"])
best_fitn = slopen*nyd["Temperature C"]+interceptn
plt.plot(nyd["Temperature C"],best_fitn,linewidth=2,c="green")
slopex, interceptx, r_valuex, p_valuex, std_errx = st.linregress(xmas["Temperature C"], xmas["Weekly_Sales"])
best_fitx = slopex*xmas["Temperature C"]+interceptx
plt.plot(xmas["Temperature C"],best_fitx,linewidth=2,c="yellow")
plt.legend()
plt.title("Weekly Sales by Temperature by Holiday")
plt.ylabel("Weekly Sales ($)")
plt.xlabel("Temperature (C)")
plt.grid()
plt.tight_layout
plt.savefig("Figures/fig24.png")

# %%
#Scatter by Fuel Price
thanks = data.loc[data["Holiday Name"]=="Thanksgiving Day"]
indep = data.loc[data["Holiday Name"]=="Independence Day"]
nyd = data.loc[data["Holiday Name"]=="New Year's Day"]
xmas= data.loc[data["Holiday Name"]=="Christmas"]
plt.scatter(thanks["Fuel_Price"],thanks["Weekly_Sales"],edgecolor="black", label="Thanksgiving")
plt.scatter(indep["Fuel_Price"],indep["Weekly_Sales"],c="red",edgecolor="black",label="Independence Day")
plt.scatter(nyd["Fuel_Price"],nyd["Weekly_Sales"],c="green",edgecolor="black",label="New Year's Day")
plt.scatter(xmas["Fuel_Price"],xmas["Weekly_Sales"],c="yellow",edgecolor="black",label="New Year's Day")
slopet, interceptt, r_valuet, p_valuet, std_errt = st.linregress(thanks["Fuel_Price"], thanks["Weekly_Sales"])
best_fitt = slopet*thanks["Fuel_Price"]+interceptt
plt.plot(thanks["Fuel_Price"],best_fitt,linewidth=2,c="blue")
slopei, intercepti, r_valuei, p_valuei, std_erri = st.linregress(indep["Fuel_Price"], indep["Weekly_Sales"])
best_fiti = slopei*indep["Fuel_Price"]+intercepti
plt.plot(indep["Fuel_Price"],best_fiti,linewidth=2,c="red")
slopen, interceptn, r_valuen, p_valuen, std_errn = st.linregress(nyd["Fuel_Price"], nyd["Weekly_Sales"])
best_fitn = slopen*nyd["Fuel_Price"]+interceptn
plt.plot(nyd["Fuel_Price"],best_fitn,linewidth=2,c="green")
slopex, interceptx, r_valuex, p_valuex, std_errx = st.linregress(xmas["Fuel_Price"], xmas["Weekly_Sales"])
best_fitx = slopex*xmas["Fuel_Price"]+interceptx
plt.plot(xmas["Fuel_Price"],best_fitx,linewidth=2,c="yellow")
plt.legend()
plt.title("Weekly Sales by Fuel Price by Holiday")
plt.ylabel("Weekly Sales ($)")
plt.xlabel("Fuel Price ($)")
plt.grid()
plt.tight_layout
plt.savefig("Figures/fig25.png")

# %%
thanks = data.loc[data["Holiday Name"]=="Thanksgiving Day"]
indep = data.loc[data["Holiday Name"]=="Independence Day"]
nyd = data.loc[data["Holiday Name"]=="New Year's Day"]
xmas= data.loc[data["Holiday Name"]=="Christmas"]
plt.scatter(thanks["CPI"],thanks["Weekly_Sales"],edgecolor="black", label="Thanksgiving")
plt.scatter(indep["CPI"],indep["Weekly_Sales"],c="red",edgecolor="black",label="Independence Day")
plt.scatter(nyd["CPI"],nyd["Weekly_Sales"],c="green",edgecolor="black",label="New Year's Day")
plt.scatter(xmas["CPI"],xmas["Weekly_Sales"],c="yellow",edgecolor="black",label="New Year's Day")
slopet, interceptt, r_valuet, p_valuet, std_errt = st.linregress(thanks["CPI"], thanks["Weekly_Sales"])
best_fitt = slopet*thanks["CPI"]+interceptt
plt.plot(thanks["CPI"],best_fitt,linewidth=2,c="blue")
slopei, intercepti, r_valuei, p_valuei, std_erri = st.linregress(indep["CPI"], indep["Weekly_Sales"])
best_fiti = slopei*indep["CPI"]+intercepti
plt.plot(indep["CPI"],best_fiti,linewidth=2,c="red")
slopen, interceptn, r_valuen, p_valuen, std_errn = st.linregress(nyd["CPI"], nyd["Weekly_Sales"])
best_fitn = slopen*nyd["CPI"]+interceptn
plt.plot(nyd["CPI"],best_fitn,linewidth=2,c="green")
slopex, interceptx, r_valuex, p_valuex, std_errx = st.linregress(xmas["CPI"], xmas["Weekly_Sales"])
best_fitx = slopex*xmas["CPI"]+interceptx
plt.plot(xmas["CPI"],best_fitx,linewidth=2,c="yellow")
plt.legend()
plt.title("Weekly Sales by Consumer Price Index by Holiday")
plt.ylabel("Weekly Sales ($)")
plt.xlabel("Consumer Price Index")
plt.grid()
plt.tight_layout
plt.savefig("Figures/fig26.png")

# %%
datea = data.groupby("Date")["Weekly_Sales"].mean()
sales=pd.DataFrame(datea)
tempa = data.groupby("Date")["Temperature C"].mean()
temp=pd.DataFrame(tempa)
fuela = data.groupby("Date")["Fuel_Price"].mean()
cpia = data.groupby("Date")["CPI"].mean()
ratea = data.groupby("Date")["Unemployment"].mean()
merge = sales.merge(tempa,on="Date")
merged = merge.merge(fuela,on="Date")
merger = merged.merge(cpia,on="Date")
bydate = merger.merge(ratea,on="Date")

# %%
#SCATTER AVERAGE WEEKLY SALES BY AVERAGE TEMPERATURE FOR ALL DAYS
ave_temperature=merge["Temperature C"]
weekly_sales=merge["Weekly_Sales"]

plt.title("Average Weekly Sales vs. Average Temperature")
plt.xlabel("Average Temperature (C)")
plt.ylabel("Average Weekly Sales ($)")
plt.grid()
plt.scatter(ave_temperature, weekly_sales, marker="o", color = "red",edgecolors="black")
plt.ticklabel_format(style='plain')
slope, intercept, r_value, p_value, std_err = st.linregress(ave_temperature, weekly_sales)
best_fit = slope*ave_temperature+intercept
plt.plot(ave_temperature,best_fit)
plt.figure(figsize=(20,10)) 
plt.tight_layout()
plt.savefig("Figures/fig27.png")

# %%
#SCATTER AVERAGE WEEKLY SALES BY AVERAGE FUEL PRICE FOR ALL DAYS
ave_fuel_price = merged["Fuel_Price"]
weekly_sales=merged["Weekly_Sales"]

plt.title("Average Weekly Sales vs. Average Fuel Price")
plt.xlabel("Average Weekly Fuel Price ($)")
plt.ylabel("Weekly Sales ($)")
plt.tight_layout()
plt.grid()
plt.scatter(ave_fuel_price, weekly_sales, marker="o", color="red",edgecolors="black")
plt.ticklabel_format(style='plain')
slope, intercept, r_value, p_value, std_err = st.linregress(ave_fuel_price, weekly_sales)
best_fit = slope*ave_fuel_price+intercept
plt.plot(ave_fuel_price,best_fit)
plt.savefig("Figures/fig28.png")

# %%
#SCATTER AVERAGE WEEKLY SALES BY AVERAGE CPI FOR ALL DAYS
weekly_sales = merger["Weekly_Sales"]
cpi = merger["CPI"]
plt.title("Average Weekly Sales vs. Average CPI")
plt.ylabel("Weekly Sales ($)")
plt.xlabel("Consumer Price Index")
plt.tight_layout()
plt.scatter(cpi,weekly_sales,marker="o", color="red",edgecolor="black")
slope, intercept, r_value, p_value, std_err = st.linregress(cpi, weekly_sales)
best_fit = slope*cpi+intercept
plt.plot(cpi,best_fit)
plt.grid()
plt.savefig("Figures/fig29.png")

# %%
#SCATTER AVERAGE UNEMPLOYMENT BY AVERAGE WEEKLY SALES FOR ALL DAYS
weekly_sales = bydate["Weekly_Sales"]
un_rate = bydate["Unemployment"]
plt.title("Average Weekly Sales vs Average Unemployment")
plt.xlabel("Unemployment Rate (%)")
plt.ylabel("Weekly Sales ($)")
plt.scatter(un_rate, weekly_sales, marker="o", color="red", edgecolor="black")
slope, intercept, r_value, p_value, std_err = st.linregress(un_rate, weekly_sales)
best_fit = slope*un_rate+intercept
plt.plot(un_rate,best_fit)
plt.grid()
plt.tight_layout()
plt.savefig("Figures/fig30.png")

# %%
datea = holiday_data.groupby("Date")["Weekly_Sales"].mean()
sales=pd.DataFrame(datea)
tempa = holiday_data.groupby("Date")["Temperature C"].mean()
temp=pd.DataFrame(tempa)
fuela = holiday_data.groupby("Date")["Fuel_Price"].mean()
cpia = holiday_data.groupby("Date")["CPI"].mean()
ratea = holiday_data.groupby("Date")["Unemployment"].mean()
merge = sales.merge(tempa,on="Date")
merged = merge.merge(fuela,on="Date")
merger = merged.merge(cpia,on="Date")
bydate = merger.merge(ratea,on="Date")

# %%
#SCATTER AVERAGE WEEKLY SALES BY AVERAGE TEMPERATURE ON HOLIDAYS
ave_temperature=merge["Temperature C"]
weekly_sales=merge["Weekly_Sales"]

plt.title("Average Weekly Sales vs. Average Temperature on Holidays for Holidays")
plt.xlabel("Average Temperature (C)")
plt.ylabel("Average Weekly Sales ($)")
plt.grid()
plt.scatter(ave_temperature, weekly_sales, marker="o", color = "red",edgecolors="black")
plt.ticklabel_format(style='plain')
slope, intercept, r_value, p_value, std_err = st.linregress(ave_temperature, weekly_sales)
best_fit = slope*ave_temperature+intercept
plt.plot(ave_temperature,best_fit)
plt.figure(figsize=(20,10)) 
plt.tight_layout()
plt.savefig("Figures/fig31.png")

# %%
#SCATTER AVERAGE WEEKLY SALES BY AVERAGE FUEL PRICE FOR HOLIDAYS
ave_fuel_price = merged["Fuel_Price"]
weekly_sales=merged["Weekly_Sales"]

plt.title("Average Weekly Sales vs. Average Fuel Price for Holidays")
plt.xlabel("Average Weekly Fuel Price ($)")
plt.ylabel("Weekly Sales ($)")
plt.tight_layout()
plt.grid()
plt.scatter(ave_fuel_price, weekly_sales, marker="o", color="red",edgecolors="black")
plt.ticklabel_format(style='plain')
slope, intercept, r_value, p_value, std_err = st.linregress(ave_fuel_price, weekly_sales)
best_fit = slope*ave_fuel_price+intercept
plt.plot(ave_fuel_price,best_fit)
plt.savefig("Figures/fig32.png")

# %%
#SCATTER AVERAGE WEEKLY SALES BY AVERAGE CPI FOR HOLIDAYS
weekly_sales = merger["Weekly_Sales"]
cpi = merger["CPI"]
plt.title("Average Weekly Sales vs. Average CPI for Holidays")
plt.ylabel("Weekly Sales ($)")
plt.xlabel("Consumer Price Index")
plt.tight_layout()
plt.scatter(cpi,weekly_sales,marker="o", color="red",edgecolor="black")
slope, intercept, r_value, p_value, std_err = st.linregress(cpi, weekly_sales)
best_fit = slope*cpi+intercept
plt.plot(cpi,best_fit)
plt.grid()
plt.savefig("Figures/fig33.png")

# %%
#SCATTER AVERAGE UNEMPLOYMENT BY AVERAGE WEEKLY SALES FOR HOLIDAYS
weekly_sales = bydate["Weekly_Sales"]
un_rate = bydate["Unemployment"]
plt.title("Average Weekly Sales vs Average Unemployment For Holidays")
plt.xlabel("Unemployment Rate (%)")
plt.ylabel("Weekly Sales ($)")
plt.scatter(un_rate, weekly_sales, marker="o", color="red", edgecolor="black")
slope, intercept, r_value, p_value, std_err = st.linregress(un_rate, weekly_sales)
best_fit = slope*un_rate+intercept
plt.plot(un_rate,best_fit)
plt.grid()
plt.tight_layout()
plt.savefig("Figures/fig34.png")

# %%
datea = data.groupby("Date")["Weekly_Sales"].mean()
sales=pd.DataFrame(datea)
tempa = data.groupby("Date")["Temperature C"].mean()
temp=pd.DataFrame(tempa)
fuela = data.groupby("Date")["Fuel_Price"].mean()
cpia = data.groupby("Date")["CPI"].mean()
ratea = data.groupby("Date")["Unemployment"].mean()
merge = sales.merge(tempa,on="Date")
merged = merge.merge(fuela,on="Date")
merger = merged.merge(cpia,on="Date")
bydate = merger.merge(ratea,on="Date")

# %%
isholi = data.groupby("Date")["Is Holiday"].describe()
isholid = pd.DataFrame(isholi)
datas = bydate.merge(isholid,on="Date")
datas.rename(columns={"top":"Is Holiday"},inplace=True)

# %%
# SCATTER AVERAGE WEEKLY SALES BY AVERAGE CPI FOR HOLIDAY AND NONHOLIDAY
cpi1 = datas["CPI"]
weekly_sales1 = datas["Weekly_Sales"]
weekly_sales2 = datas.loc[datas["Is Holiday"] != "No Holiday"]["Weekly_Sales"]
cpi2 = datas.loc[datas["Is Holiday"] != "No Holiday"]["CPI"]
plt.tight_layout()
plt.figure(figsize=(20,10)) 
plt.grid()
plt.title("Average Weekly Sales vs. Average CPI",fontsize = 30)
plt.xlabel("Average Consumer Price Index",fontsize=20)
plt.ylabel("Average Weekly Sales ($)",fontsize = 20)

plt.scatter(cpi1, weekly_sales1, marker="o",color = "blue",edgecolors="black",label="All Days")
plt.scatter(cpi2, weekly_sales2, marker="o", color = "red",edgecolors="black",label = "Holidays")
slope2, intercept2, r_value2, p_value2, std_err2 = st.linregress(cpi2, weekly_sales2)
best_fit2 = slope2*cpi2+intercept2
slope1, intercept1, r_value1, p_value1, std_err1 = st.linregress(cpi1, weekly_sales1)
best_fit1 = slope1*cpi1+intercept1
plt.plot(cpi1,best_fit1,linewidth=5,c="blue")
plt.plot(cpi2,best_fit2,linewidth=5,c="red")
plt.legend()
plt.tight_layout()
plt.savefig("Figures/fig35.png")

# %%
# SCATTER AVERAGE WEEKLY SALES BY AVERAGE FUEL PRICE FOR HOLIDAY AND NONHOLIDAY
cpi1 = datas["Fuel_Price"]
weekly_sales1 = datas["Weekly_Sales"]
weekly_sales2 = datas.loc[datas["Is Holiday"] != "No Holiday"]["Weekly_Sales"]
cpi2 = datas.loc[datas["Is Holiday"] != "No Holiday"]["Fuel_Price"]
plt.tight_layout()
plt.figure(figsize=(20,10)) 
plt.grid()
plt.title("Average Weekly Sales vs. Average Fuel Price",fontsize = 30)
plt.xlabel("Average Fuel Price ($)",fontsize=20)
plt.ylabel("Average Weekly Sales ($)",fontsize = 20)

plt.scatter(cpi1, weekly_sales1, marker="o",color = "blue",edgecolors="black",label="All Days")
plt.scatter(cpi2, weekly_sales2, marker="o", color = "red",edgecolors="black",label = "Holidays")
slope2, intercept2, r_value2, p_value2, std_err2 = st.linregress(cpi2, weekly_sales2)
best_fit2 = slope2*cpi2+intercept2
slope1, intercept1, r_value1, p_value1, std_err1 = st.linregress(cpi1, weekly_sales1)
best_fit1 = slope1*cpi1+intercept1
plt.plot(cpi1,best_fit1,linewidth=5,c="blue")
plt.plot(cpi2,best_fit2,linewidth=5,c="red")
plt.legend()
plt.tight_layout()
plt.savefig("Figures/fig36.png")

# %%
# SCATTER AVERAGE WEEKLY SALES BY AVERAGE TEMPERATURE FOR HOLIDAY AND NONHOLIDAY
cpi1 = datas["Temperature C"]
weekly_sales1 = datas["Weekly_Sales"]
weekly_sales2 = datas.loc[datas["Is Holiday"] != "No Holiday"]["Weekly_Sales"]
cpi2 = datas.loc[datas["Is Holiday"] != "No Holiday"]["Temperature C"]
plt.figure(figsize=(20,10))
plt.grid()
plt.title("Average Weekly Sales vs. Average Temperature",fontsize = 30)
plt.xlabel("Average Temperature (C))",fontsize=20)
plt.ylabel("Average Weekly Sales ($)",fontsize = 20)

plt.scatter(cpi1, weekly_sales1, marker="o",color = "blue",edgecolors="black",label="All Days")
plt.scatter(cpi2, weekly_sales2, marker="o", color = "red",edgecolors="black",label = "Holidays")
slope2, intercept2, r_value2, p_value2, std_err2 = st.linregress(cpi2, weekly_sales2)
best_fit2 = slope2*cpi2+intercept2
slope1, intercept1, r_value1, p_value1, std_err1 = st.linregress(cpi1, weekly_sales1)
best_fit1 = slope1*cpi1+intercept1
plt.plot(cpi1,best_fit1,linewidth=5,c="blue")
plt.plot(cpi2,best_fit2,linewidth=5,c="red")
plt.legend()
plt.tight_layout()
plt.savefig("Figures/fig37.png")

# %%
# SCATTER AVERAGE WEEKLY SALES BY AVERAGE UNEMPLOYMENT RATE FOR HOLIDAY AND NONHOLIDAY
cpi1 = datas["Unemployment"]
weekly_sales1 = datas["Weekly_Sales"]
weekly_sales2 = datas.loc[datas["Is Holiday"] != "No Holiday"]["Weekly_Sales"]
cpi2 = datas.loc[datas["Is Holiday"] != "No Holiday"]["Unemployment"]
plt.tight_layout()
plt.figure(figsize=(20,10)) 
plt.grid()
plt.title("Average Weekly Sales vs. Average Unemployment",fontsize = 30)
plt.xlabel("Average Unemployment Rate (%)",fontsize=20)
plt.ylabel("Average Weekly Sales ($)",fontsize = 20)

plt.scatter(cpi1, weekly_sales1, marker="o",color = "blue",edgecolors="black",label="All Days")
plt.scatter(cpi2, weekly_sales2, marker="o", color = "red",edgecolors="black",label = "Holidays")
slope2, intercept2, r_value2, p_value2, std_err2 = st.linregress(cpi2, weekly_sales2)
best_fit2 = slope2*cpi2+intercept2
slope1, intercept1, r_value1, p_value1, std_err1 = st.linregress(cpi1, weekly_sales1)
best_fit1 = slope1*cpi1+intercept1
plt.plot(cpi1,best_fit1,linewidth=5,c="blue")
plt.plot(cpi2,best_fit2,linewidth=5,c="red")
plt.legend()
plt.figure(figsize=(20,20))
plt.tight_layout()
plt.savefig("Figures/fig38.png")
